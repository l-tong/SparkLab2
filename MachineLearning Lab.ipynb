# %% [markdown]
# # Lab 3 - Spark MLlib
#
# "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P, improves with experience E"
# -Tom M. Mitchell
#
# Machine Learning - the science of getting computers to act without being explicitly programmed
#
# MLlib is Spark’s machine learning (ML) library. Its goal is to make practical machine learning scalable and easy. It consists of common learning algorithms and utilities, including classification, regression, clustering, collaborative filtering (this example!), dimensionality reduction, as well as lower-level optimization primitives and higher-level pipeline APIs.
#
# It divides into two packages:
# 1. spark.mllib contains the original API built on top of RDDs.
# 2. spark.ml provides higher-level API built on top of DataFrames for constructing ML pipelines.
#
#
# Using spark.ml is recommended because with DataFrames the API is more versatile and flexible. But we will keep supporting spark.mllib along with the development of spark.ml. Users should be comfortable using spark.mllib features and expect more features coming.
#
# http://spark.apache.org/docs/latest/mllib-guide.html
#
# ## Online Purchase Recommendations
#
# Learn how to create a recommendation engine using the Alternating Least Squares algorithm in Spark's machine learning library
#
# <img src='https://raw.githubusercontent.com/rosswlewis/RecommendationPoT/master/ALS.png' width="70%" height="70%"></img>
#
# ## The data
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.  The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# http://archive.ics.uci.edu/ml/datasets/Online+Retail
#
# <img src='https://raw.githubusercontent.com/rosswlewis/RecommendationPoT/master/FullFile.png' width="80%" height="80%"></img>

# %% [markdown]
# ## Step 1 - Create an RDD from the CSV File
# ### 1.1 - Download the data

# %%
#Download the data from github to the local directory
# !rm 'OnlineRetail.csv.gz' -f
# !wget https://raw.githubusercontent.com/rosswlewis/RecommendationPoT/master/OnlineRetail.csv.gz
# Out:
# --2017-02-09 12:54:48--  https://raw.githubusercontent.com/rosswlewis/RecommendationPoT/master/OnlineRetail.csv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7483128 (7.1M) [application/octet-stream]
# Saving to: ‘OnlineRetail.csv.gz’
#
# 100%[======================================>] 7,483,128   --.-K/s   in 0.1s
#
# 2017-02-09 12:54:48 (66.2 MB/s) - ‘OnlineRetail.csv.gz’ saved [7483128/7483128]

# %% [markdown]
# ### 1.2 - Put the csv into an RDD (at first, each row in the RDD is a string which correlates to a line in the csv) and show the first three lines.
# <br>
#  <div class="panel-group" id="accordion-12">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-1" href="#collapse1-12">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-12" class="panel-collapse collapse">
#       <div class="panel-body">Use the Spark context (sc) to get the list of possible methods.  <i>sc.&lt;TAB&gt;</i></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-12" href="#collapse2-12">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-12" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>textFile()</i> method</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-12" href="#collapse3-12">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-12" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# loadRetailData = sc.textFile("OnlineRetail.csv.gz")<br>
# loadRetailData.take(3)<br></div>
#     </div>
#   </div>
# </div>

# %%
loadRetailData = sc.textFile("OnlineRetail.csv.gz")
loadRetailData.take(3)
# Out:
# [u'InvoiceNo,StockCode,Description,Quantity,InvoiceDate,UnitPrice,CustomerID,Country',
#  u'536365,85123A,WHITE HANGING HEART T-LIGHT HOLDER,6,12/1/10 8:26,2.55,17850,United Kingdom',
#  u'536365,71053,WHITE METAL LANTERN,6,12/1/10 8:26,3.39,17850,United Kingdom']

# %% [markdown]
# ## Step 2 - Prepare and shape the data:  "80% of a Data Scientists  job"

# %% [markdown]
# ### 2.1 - Remove the header from the RDD and split the remaining lines by comma.
# <br>
#  <div class="panel-group" id="accordion-21">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-21" href="#collapse1-21">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-21" class="panel-collapse collapse">
#       <div class="panel-body">The header is the first line in the RDD -- use <i>first()</i> to obtain it.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-21" href="#collapse2-21">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-21" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>filter()</i> method to filter out all lines which are not equal to the header line.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-21" href="#collapse3-21">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-21" class="panel-collapse collapse">
#       <div class="panel-body">Map the <i>split()</i> method to the remaining lines to split on ","</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-21" href="#collapse4-21">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-21" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#
# header = loadRetailData.first()<br>
# splitColumns = loadRetailData.filter(lambda line: line != header).map(lambda l: l.split(","))</div>
#     </div>
#   </div>
# </div>

# %%
header = loadRetailData.first()
# remove the first row and split by comma into a map object
splitColumns = loadRetailData.filter(lambda line: line != header).map(lambda l: l.split(","))

# %% [markdown]
# ### 2.2 - Filter the remaining lines using <a href="https://docs.python.org/2.6/howto/regex.html">regular expressions</a>
# The original file at UCI's Machine Learning Repository has commas in the product description.  Those have been removed to expediate the lab.
# Only keep rows that have a quantity greater than 0, a non-empty customerID, and a non-blank stock code after removing non-numeric characters.<br><br>
#  <div class="panel-group" id="accordion-22">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-22" href="#collapse1-22">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-22" class="panel-collapse collapse">
#       <div class="panel-body">Examine the header to determine which fields need to be used to filter the data.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-22" href="#collapse2-22">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-22" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>filter()</i> method for the first two requirements.   Note -- you may have to cast values.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-22" href="#collapse3-22">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-22" class="panel-collapse collapse">
#       <div class="panel-body">Look at the <i><a href="https://docs.python.org/2.6/howto/regex.html">re.sub()</a></i> method</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-22" href="#collapse4-22">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-22" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# import re<br>
# filteredRetailData = splitColumns.filter(lambda l: int(l[3]) > 0 and len(re.sub("\D", "", l[1])) != 0 and l[6] != "")</div>
#     </div>
#   </div>
# </div>

# %%
import re
filteredRetailData = splitColumns.filter(lambda l: int(l[3]) > 0 and len(re.sub("\D", "", l[1])) != 0 and l[6] != "")
filteredRetailData.collect()
# Out:
# [[u'536365',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 8:26',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'71053',
#   u'WHITE METAL LANTERN',
#   u'6',
#   u'12/1/10 8:26',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'84406B',
#   u'CREAM CUPID HEARTS COAT HANGER',
#   u'8',
#   u'12/1/10 8:26',
#   u'2.75',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'84029G',
#   u'KNITTED UNION FLAG HOT WATER BOTTLE',
#   u'6',
#   u'12/1/10 8:26',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'84029E',
#   u'RED WOOLLY HOTTIE WHITE HEART.',
#   u'6',
#   u'12/1/10 8:26',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'22752',
#   u'SET 7 BABUSHKA NESTING BOXES',
#   u'2',
#   u'12/1/10 8:26',
#   u'7.65',
#   u'17850',
#   u'United Kingdom'],
#  [u'536365',
#   u'21730',
#   u'GLASS STAR FROSTED T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 8:26',
#   u'4.25',
#   u'17850',
#   u'United Kingdom'],
#  [u'536366',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'6',
#   u'12/1/10 8:28',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536366',
#   u'22632',
#   u'HAND WARMER RED POLKA DOT',
#   u'6',
#   u'12/1/10 8:28',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536367',
#   u'84879',
#   u'ASSORTED COLOUR BIRD ORNAMENT',
#   u'32',
#   u'12/1/10 8:34',
#   u'1.69',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22745',
#   u"POPPY'S PLAYHOUSE BEDROOM ",
#   u'6',
#   u'12/1/10 8:34',
#   u'2.1',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22748',
#   u"POPPY'S PLAYHOUSE KITCHEN",
#   u'6',
#   u'12/1/10 8:34',
#   u'2.1',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22749',
#   u'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   u'8',
#   u'12/1/10 8:34',
#   u'3.75',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22310',
#   u'IVORY KNITTED MUG COSY ',
#   u'6',
#   u'12/1/10 8:34',
#   u'1.65',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'84969',
#   u'BOX OF 6 ASSORTED COLOUR TEASPOONS',
#   u'6',
#   u'12/1/10 8:34',
#   u'4.25',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22623',
#   u'BOX OF VINTAGE JIGSAW BLOCKS ',
#   u'3',
#   u'12/1/10 8:34',
#   u'4.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'22622',
#   u'BOX OF VINTAGE ALPHABET BLOCKS',
#   u'2',
#   u'12/1/10 8:34',
#   u'9.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'21754',
#   u'HOME BUILDING BLOCK WORD',
#   u'3',
#   u'12/1/10 8:34',
#   u'5.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'21755',
#   u'LOVE BUILDING BLOCK WORD',
#   u'3',
#   u'12/1/10 8:34',
#   u'5.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'21777',
#   u'RECIPE BOX WITH METAL HEART',
#   u'4',
#   u'12/1/10 8:34',
#   u'7.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536367',
#   u'48187',
#   u'DOORMAT NEW ENGLAND',
#   u'4',
#   u'12/1/10 8:34',
#   u'7.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536368',
#   u'22960',
#   u'JAM MAKING SET WITH JARS',
#   u'6',
#   u'12/1/10 8:34',
#   u'4.25',
#   u'13047',
#   u'United Kingdom'],
#  [u'536368',
#   u'22913',
#   u'RED COAT RACK PARIS FASHION',
#   u'3',
#   u'12/1/10 8:34',
#   u'4.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536368',
#   u'22912',
#   u'YELLOW COAT RACK PARIS FASHION',
#   u'3',
#   u'12/1/10 8:34',
#   u'4.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536368',
#   u'22914',
#   u'BLUE COAT RACK PARIS FASHION',
#   u'3',
#   u'12/1/10 8:34',
#   u'4.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536369',
#   u'21756',
#   u'BATH BUILDING BLOCK WORD',
#   u'3',
#   u'12/1/10 8:35',
#   u'5.95',
#   u'13047',
#   u'United Kingdom'],
#  [u'536370',
#   u'22728',
#   u'ALARM CLOCK BAKELIKE PINK',
#   u'24',
#   u'12/1/10 8:45',
#   u'3.75',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22727',
#   u'ALARM CLOCK BAKELIKE RED ',
#   u'24',
#   u'12/1/10 8:45',
#   u'3.75',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22726',
#   u'ALARM CLOCK BAKELIKE GREEN',
#   u'12',
#   u'12/1/10 8:45',
#   u'3.75',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21724',
#   u'PANDA AND BUNNIES STICKER SHEET',
#   u'12',
#   u'12/1/10 8:45',
#   u'0.85',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21883',
#   u'STARS GIFT TAPE ',
#   u'24',
#   u'12/1/10 8:45',
#   u'0.65',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'10002',
#   u'INFLATABLE POLITICAL GLOBE ',
#   u'48',
#   u'12/1/10 8:45',
#   u'0.85',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21791',
#   u'VINTAGE HEADS AND TAILS CARD GAME ',
#   u'24',
#   u'12/1/10 8:45',
#   u'1.25',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21035',
#   u'SET/2 RED RETROSPOT TEA TOWELS ',
#   u'18',
#   u'12/1/10 8:45',
#   u'2.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22326',
#   u'ROUND SNACK BOXES SET OF4 WOODLAND ',
#   u'24',
#   u'12/1/10 8:45',
#   u'2.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22629',
#   u'SPACEBOY LUNCH BOX ',
#   u'24',
#   u'12/1/10 8:45',
#   u'1.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22659',
#   u'LUNCH BOX I LOVE LONDON',
#   u'24',
#   u'12/1/10 8:45',
#   u'1.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22631',
#   u'CIRCUS PARADE LUNCH BOX ',
#   u'24',
#   u'12/1/10 8:45',
#   u'1.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22661',
#   u'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   u'20',
#   u'12/1/10 8:45',
#   u'0.85',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21731',
#   u'RED TOADSTOOL LED NIGHT LIGHT',
#   u'24',
#   u'12/1/10 8:45',
#   u'1.65',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22900',
#   u' SET 2 TEA TOWELS I LOVE LONDON ',
#   u'24',
#   u'12/1/10 8:45',
#   u'2.95',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'21913',
#   u'VINTAGE SEASIDE JIGSAW PUZZLES',
#   u'12',
#   u'12/1/10 8:45',
#   u'3.75',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22540',
#   u'MINI JIGSAW CIRCUS PARADE ',
#   u'24',
#   u'12/1/10 8:45',
#   u'0.42',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22544',
#   u'MINI JIGSAW SPACEBOY',
#   u'24',
#   u'12/1/10 8:45',
#   u'0.42',
#   u'12583',
#   u'France'],
#  [u'536370',
#   u'22492',
#   u'MINI PAINT SET VINTAGE ',
#   u'36',
#   u'12/1/10 8:45',
#   u'0.65',
#   u'12583',
#   u'France'],
#  [u'536371',
#   u'22086',
#   u"PAPER CHAIN KIT 50'S CHRISTMAS ",
#   u'80',
#   u'12/1/10 9:00',
#   u'2.55',
#   u'13748',
#   u'United Kingdom'],
#  [u'536372',
#   u'22632',
#   u'HAND WARMER RED POLKA DOT',
#   u'6',
#   u'12/1/10 9:01',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536372',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'6',
#   u'12/1/10 9:01',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 9:02',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'71053',
#   u'WHITE METAL LANTERN',
#   u'6',
#   u'12/1/10 9:02',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'84406B',
#   u'CREAM CUPID HEARTS COAT HANGER',
#   u'8',
#   u'12/1/10 9:02',
#   u'2.75',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'20679',
#   u'EDWARDIAN PARASOL RED',
#   u'6',
#   u'12/1/10 9:02',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'37370',
#   u'RETRO COFFEE MUGS ASSORTED',
#   u'6',
#   u'12/1/10 9:02',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'21871',
#   u'SAVE THE PLANET MUG',
#   u'6',
#   u'12/1/10 9:02',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'21071',
#   u'VINTAGE BILLBOARD DRINK ME MUG',
#   u'6',
#   u'12/1/10 9:02',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'21068',
#   u'VINTAGE BILLBOARD LOVE/HATE MUG',
#   u'6',
#   u'12/1/10 9:02',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'82483',
#   u'WOOD 2 DRAWER CABINET WHITE FINISH',
#   u'2',
#   u'12/1/10 9:02',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'82486',
#   u'WOOD S/3 CABINET ANT WHITE FINISH',
#   u'4',
#   u'12/1/10 9:02',
#   u'6.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'82482',
#   u'WOODEN PICTURE FRAME WHITE FINISH',
#   u'6',
#   u'12/1/10 9:02',
#   u'2.1',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'82494L',
#   u'WOODEN FRAME ANTIQUE WHITE ',
#   u'6',
#   u'12/1/10 9:02',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'84029G',
#   u'KNITTED UNION FLAG HOT WATER BOTTLE',
#   u'6',
#   u'12/1/10 9:02',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'84029E',
#   u'RED WOOLLY HOTTIE WHITE HEART.',
#   u'6',
#   u'12/1/10 9:02',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'22752',
#   u'SET 7 BABUSHKA NESTING BOXES',
#   u'2',
#   u'12/1/10 9:02',
#   u'7.65',
#   u'17850',
#   u'United Kingdom'],
#  [u'536373',
#   u'21730',
#   u'GLASS STAR FROSTED T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 9:02',
#   u'4.25',
#   u'17850',
#   u'United Kingdom'],
#  [u'536374',
#   u'21258',
#   u'VICTORIAN SEWING BOX LARGE',
#   u'32',
#   u'12/1/10 9:09',
#   u'10.95',
#   u'15100',
#   u'United Kingdom'],
#  [u'536375',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 9:32',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'71053',
#   u'WHITE METAL LANTERN',
#   u'6',
#   u'12/1/10 9:32',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'84406B',
#   u'CREAM CUPID HEARTS COAT HANGER',
#   u'8',
#   u'12/1/10 9:32',
#   u'2.75',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'20679',
#   u'EDWARDIAN PARASOL RED',
#   u'6',
#   u'12/1/10 9:32',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'37370',
#   u'RETRO COFFEE MUGS ASSORTED',
#   u'6',
#   u'12/1/10 9:32',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'21871',
#   u'SAVE THE PLANET MUG',
#   u'6',
#   u'12/1/10 9:32',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'21071',
#   u'VINTAGE BILLBOARD DRINK ME MUG',
#   u'6',
#   u'12/1/10 9:32',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'21068',
#   u'VINTAGE BILLBOARD LOVE/HATE MUG',
#   u'6',
#   u'12/1/10 9:32',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'82483',
#   u'WOOD 2 DRAWER CABINET WHITE FINISH',
#   u'2',
#   u'12/1/10 9:32',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'82486',
#   u'WOOD S/3 CABINET ANT WHITE FINISH',
#   u'4',
#   u'12/1/10 9:32',
#   u'6.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'82482',
#   u'WOODEN PICTURE FRAME WHITE FINISH',
#   u'6',
#   u'12/1/10 9:32',
#   u'2.1',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'82494L',
#   u'WOODEN FRAME ANTIQUE WHITE ',
#   u'6',
#   u'12/1/10 9:32',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'84029G',
#   u'KNITTED UNION FLAG HOT WATER BOTTLE',
#   u'6',
#   u'12/1/10 9:32',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'84029E',
#   u'RED WOOLLY HOTTIE WHITE HEART.',
#   u'6',
#   u'12/1/10 9:32',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'22752',
#   u'SET 7 BABUSHKA NESTING BOXES',
#   u'2',
#   u'12/1/10 9:32',
#   u'7.65',
#   u'17850',
#   u'United Kingdom'],
#  [u'536375',
#   u'21730',
#   u'GLASS STAR FROSTED T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 9:32',
#   u'4.25',
#   u'17850',
#   u'United Kingdom'],
#  [u'536376',
#   u'22114',
#   u'HOT WATER BOTTLE TEA AND SYMPATHY',
#   u'48',
#   u'12/1/10 9:32',
#   u'3.45',
#   u'15291',
#   u'United Kingdom'],
#  [u'536376',
#   u'21733',
#   u'RED HANGING HEART T-LIGHT HOLDER',
#   u'64',
#   u'12/1/10 9:32',
#   u'2.55',
#   u'15291',
#   u'United Kingdom'],
#  [u'536377',
#   u'22632',
#   u'HAND WARMER RED POLKA DOT',
#   u'6',
#   u'12/1/10 9:34',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536377',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'6',
#   u'12/1/10 9:34',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536378',
#   u'22386',
#   u'JUMBO BAG PINK POLKADOT',
#   u'10',
#   u'12/1/10 9:37',
#   u'1.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'85099C',
#   u'JUMBO  BAG BAROQUE BLACK WHITE',
#   u'10',
#   u'12/1/10 9:37',
#   u'1.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21033',
#   u'JUMBO BAG CHARLIE AND LOLA TOYS',
#   u'10',
#   u'12/1/10 9:37',
#   u'2.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'20723',
#   u'STRAWBERRY CHARLOTTE BAG',
#   u'10',
#   u'12/1/10 9:37',
#   u'0.85',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'84997B',
#   u'RED 3 PIECE RETROSPOT CUTLERY SET',
#   u'12',
#   u'12/1/10 9:37',
#   u'3.75',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'84997C',
#   u'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   u'6',
#   u'12/1/10 9:37',
#   u'3.75',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21094',
#   u'SET/6 RED SPOTTY PAPER PLATES',
#   u'12',
#   u'12/1/10 9:37',
#   u'0.85',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'20725',
#   u'LUNCH BAG RED RETROSPOT',
#   u'10',
#   u'12/1/10 9:37',
#   u'1.65',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21559',
#   u'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   u'6',
#   u'12/1/10 9:37',
#   u'2.55',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'22352',
#   u'LUNCH BOX WITH CUTLERY RETROSPOT ',
#   u'6',
#   u'12/1/10 9:37',
#   u'2.55',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21212',
#   u'PACK OF 72 RETROSPOT CAKE CASES',
#   u'120',
#   u'12/1/10 9:37',
#   u'0.42',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21975',
#   u'PACK OF 60 DINOSAUR CAKE CASES',
#   u'24',
#   u'12/1/10 9:37',
#   u'0.55',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21977',
#   u'PACK OF 60 PINK PAISLEY CAKE CASES',
#   u'24',
#   u'12/1/10 9:37',
#   u'0.55',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'84991',
#   u'60 TEATIME FAIRY CAKE CASES',
#   u'24',
#   u'12/1/10 9:37',
#   u'0.55',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'84519A',
#   u'TOMATO CHARLIE+LOLA COASTER SET',
#   u'6',
#   u'12/1/10 9:37',
#   u'2.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'85183B',
#   u'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#   u'48',
#   u'12/1/10 9:37',
#   u'1.25',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'85071B',
#   u'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#   u'96',
#   u'12/1/10 9:37',
#   u'0.38',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21931',
#   u'JUMBO STORAGE BAG SUKI',
#   u'10',
#   u'12/1/10 9:37',
#   u'1.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536378',
#   u'21929',
#   u'JUMBO BAG PINK VINTAGE PAISLEY',
#   u'10',
#   u'12/1/10 9:37',
#   u'1.95',
#   u'14688',
#   u'United Kingdom'],
#  [u'536380',
#   u'22961',
#   u'JAM MAKING SET PRINTED',
#   u'24',
#   u'12/1/10 9:41',
#   u'1.45',
#   u'17809',
#   u'United Kingdom'],
#  [u'536381',
#   u'22139',
#   u'RETROSPOT TEA SET CERAMIC 11 PC ',
#   u'23',
#   u'12/1/10 9:41',
#   u'4.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'84854',
#   u'GIRLY PINK TOOL SET',
#   u'5',
#   u'12/1/10 9:41',
#   u'4.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22411',
#   u'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   u'10',
#   u'12/1/10 9:41',
#   u'1.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'82567',
#   u'AIRLINE LOUNGEMETAL SIGN',
#   u'2',
#   u'12/1/10 9:41',
#   u'2.1',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21672',
#   u'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   u'6',
#   u'12/1/10 9:41',
#   u'1.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22774',
#   u'RED DRAWER KNOB ACRYLIC EDWARDIAN',
#   u'24',
#   u'12/1/10 9:41',
#   u'1.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22771',
#   u'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',
#   u'24',
#   u'12/1/10 9:41',
#   u'1.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'71270',
#   u'PHOTO CLIP LINE',
#   u'1',
#   u'12/1/10 9:41',
#   u'1.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22262',
#   u'FELT EGG COSY CHICKEN',
#   u'1',
#   u'12/1/10 9:41',
#   u'0.85',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22637',
#   u'PIGGY BANK RETROSPOT ',
#   u'1',
#   u'12/1/10 9:41',
#   u'2.55',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21934',
#   u'SKULL SHOULDER BAG',
#   u'10',
#   u'12/1/10 9:41',
#   u'1.65',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21169',
#   u"YOU'RE CONFUSING ME METAL SIGN ",
#   u'3',
#   u'12/1/10 9:41',
#   u'1.69',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21166',
#   u'COOK WITH WINE METAL SIGN ',
#   u'1',
#   u'12/1/10 9:41',
#   u'1.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21175',
#   u'GIN + TONIC DIET METAL SIGN',
#   u'2',
#   u'12/1/10 9:41',
#   u'2.1',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'37444A',
#   u'YELLOW BREAKFAST CUP AND SAUCER',
#   u'1',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'37444C',
#   u'PINK BREAKFAST CUP AND SAUCER ',
#   u'1',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22086',
#   u"PAPER CHAIN KIT 50'S CHRISTMAS ",
#   u'4',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22083',
#   u'PAPER CHAIN KIT RETROSPOT',
#   u'1',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'84971S',
#   u'SMALL HEART FLOWERS HOOK ',
#   u'6',
#   u'12/1/10 9:41',
#   u'0.85',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'71270',
#   u'PHOTO CLIP LINE',
#   u'3',
#   u'12/1/10 9:41',
#   u'1.25',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'47580',
#   u'TEA TIME DES TEA COSY',
#   u'2',
#   u'12/1/10 9:41',
#   u'2.55',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22261',
#   u'FELT EGG COSY WHITE RABBIT ',
#   u'1',
#   u'12/1/10 9:41',
#   u'0.85',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'84832',
#   u'ZINC WILLIE WINKIE  CANDLE STICK',
#   u'1',
#   u'12/1/10 9:41',
#   u'0.85',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22644',
#   u'CERAMIC CHERRY CAKE MONEY BANK',
#   u'1',
#   u'12/1/10 9:41',
#   u'1.45',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21533',
#   u'RETROSPOT LARGE MILK JUG',
#   u'1',
#   u'12/1/10 9:41',
#   u'4.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21557',
#   u'SET OF 6 FUNKY BEAKERS',
#   u'2',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'15056BL',
#   u'EDWARDIAN PARASOL BLACK',
#   u'2',
#   u'12/1/10 9:41',
#   u'5.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'15056N',
#   u'EDWARDIAN PARASOL NATURAL',
#   u'2',
#   u'12/1/10 9:41',
#   u'5.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22646',
#   u'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   u'4',
#   u'12/1/10 9:41',
#   u'1.45',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22176',
#   u'BLUE OWL SOFT TOY',
#   u'1',
#   u'12/1/10 9:41',
#   u'2.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22438',
#   u'BALLOON ART MAKE YOUR OWN FLOWERS',
#   u'1',
#   u'12/1/10 9:41',
#   u'1.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21731',
#   u'RED TOADSTOOL LED NIGHT LIGHT',
#   u'2',
#   u'12/1/10 9:41',
#   u'1.65',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22778',
#   u'GLASS CLOCHE SMALL',
#   u'3',
#   u'12/1/10 9:41',
#   u'3.95',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'22719',
#   u'GUMBALL MONOCHROME COAT RACK',
#   u'36',
#   u'12/1/10 9:41',
#   u'1.06',
#   u'15311',
#   u'United Kingdom'],
#  [u'536381',
#   u'21523',
#   u'DOORMAT FANCY FONT HOME SWEET HOME',
#   u'10',
#   u'12/1/10 9:41',
#   u'6.75',
#   u'15311',
#   u'United Kingdom'],
#  [u'536382',
#   u'10002',
#   u'INFLATABLE POLITICAL GLOBE ',
#   u'12',
#   u'12/1/10 9:45',
#   u'0.85',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'21912',
#   u'VINTAGE SNAKES & LADDERS',
#   u'8',
#   u'12/1/10 9:45',
#   u'3.75',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'21832',
#   u'CHOCOLATE CALCULATOR',
#   u'12',
#   u'12/1/10 9:45',
#   u'1.65',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22411',
#   u'JUMBO SHOPPER VINTAGE RED PAISLEY',
#   u'10',
#   u'12/1/10 9:45',
#   u'1.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22379',
#   u'RECYCLING BAG RETROSPOT ',
#   u'10',
#   u'12/1/10 9:45',
#   u'2.1',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22381',
#   u'TOY TIDY PINK POLKADOT',
#   u'50',
#   u'12/1/10 9:45',
#   u'1.85',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22798',
#   u'ANTIQUE GLASS DRESSING TABLE POT',
#   u'8',
#   u'12/1/10 9:45',
#   u'2.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22726',
#   u'ALARM CLOCK BAKELIKE GREEN',
#   u'4',
#   u'12/1/10 9:45',
#   u'3.75',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22926',
#   u'IVORY GIANT GARDEN THERMOMETER',
#   u'12',
#   u'12/1/10 9:45',
#   u'5.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22839',
#   u'3 TIER CAKE TIN GREEN AND CREAM',
#   u'2',
#   u'12/1/10 9:45',
#   u'14.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22838',
#   u'3 TIER CAKE TIN RED AND CREAM',
#   u'2',
#   u'12/1/10 9:45',
#   u'14.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536382',
#   u'22783',
#   u'SET 3 WICKER OVAL BASKETS W LIDS',
#   u'4',
#   u'12/1/10 9:45',
#   u'16.95',
#   u'16098',
#   u'United Kingdom'],
#  [u'536384',
#   u'82484',
#   u'WOOD BLACK BOARD ANT WHITE FINISH',
#   u'3',
#   u'12/1/10 9:53',
#   u'6.45',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'84755',
#   u'COLOUR GLASS T-LIGHT HOLDER HANGING',
#   u'48',
#   u'12/1/10 9:53',
#   u'0.65',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22464',
#   u'HANGING METAL HEART LANTERN',
#   u'12',
#   u'12/1/10 9:53',
#   u'1.65',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'21324',
#   u'HANGING MEDINA LANTERN SMALL',
#   u'6',
#   u'12/1/10 9:53',
#   u'2.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22457',
#   u'NATURAL SLATE HEART CHALKBOARD ',
#   u'12',
#   u'12/1/10 9:53',
#   u'2.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22469',
#   u'HEART OF WICKER SMALL',
#   u'40',
#   u'12/1/10 9:53',
#   u'1.45',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22470',
#   u'HEART OF WICKER LARGE',
#   u'40',
#   u'12/1/10 9:53',
#   u'2.55',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22224',
#   u'WHITE LOVEBIRD LANTERN',
#   u'6',
#   u'12/1/10 9:53',
#   u'2.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'21340',
#   u'CLASSIC METAL BIRDCAGE PLANT HOLDER',
#   u'2',
#   u'12/1/10 9:53',
#   u'12.75',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22189',
#   u'CREAM HEART CARD HOLDER',
#   u'4',
#   u'12/1/10 9:53',
#   u'3.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22427',
#   u'ENAMEL FLOWER JUG CREAM',
#   u'3',
#   u'12/1/10 9:53',
#   u'5.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22428',
#   u'ENAMEL FIRE BUCKET CREAM',
#   u'6',
#   u'12/1/10 9:53',
#   u'6.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536384',
#   u'22424',
#   u'ENAMEL BREAD BIN CREAM',
#   u'8',
#   u'12/1/10 9:53',
#   u'10.95',
#   u'18074',
#   u'United Kingdom'],
#  [u'536385',
#   u'22783',
#   u'SET 3 WICKER OVAL BASKETS W LIDS',
#   u'1',
#   u'12/1/10 9:56',
#   u'19.95',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'22961',
#   u'JAM MAKING SET PRINTED',
#   u'12',
#   u'12/1/10 9:56',
#   u'1.45',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'22960',
#   u'JAM MAKING SET WITH JARS',
#   u'6',
#   u'12/1/10 9:56',
#   u'4.25',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'22663',
#   u'JUMBO BAG DOLLY GIRL DESIGN',
#   u'10',
#   u'12/1/10 9:56',
#   u'1.95',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'85049A',
#   u'TRADITIONAL CHRISTMAS RIBBONS',
#   u'12',
#   u'12/1/10 9:56',
#   u'1.25',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'22168',
#   u'ORGANISER WOOD ANTIQUE WHITE ',
#   u'2',
#   u'12/1/10 9:56',
#   u'8.5',
#   u'17420',
#   u'United Kingdom'],
#  [u'536385',
#   u'22662',
#   u'LUNCH BAG DOLLY GIRL DESIGN',
#   u'10',
#   u'12/1/10 9:56',
#   u'1.65',
#   u'17420',
#   u'United Kingdom'],
#  [u'536386',
#   u'84880',
#   u'WHITE WIRE EGG HOLDER',
#   u'36',
#   u'12/1/10 9:57',
#   u'4.95',
#   u'16029',
#   u'United Kingdom'],
#  [u'536386',
#   u'85099C',
#   u'JUMBO  BAG BAROQUE BLACK WHITE',
#   u'100',
#   u'12/1/10 9:57',
#   u'1.65',
#   u'16029',
#   u'United Kingdom'],
#  [u'536386',
#   u'85099B',
#   u'JUMBO BAG RED RETROSPOT',
#   u'100',
#   u'12/1/10 9:57',
#   u'1.65',
#   u'16029',
#   u'United Kingdom'],
#  [u'536387',
#   u'79321',
#   u'CHILLI LIGHTS',
#   u'192',
#   u'12/1/10 9:58',
#   u'3.82',
#   u'16029',
#   u'United Kingdom'],
#  [u'536387',
#   u'22780',
#   u'LIGHT GARLAND BUTTERFILES PINK',
#   u'192',
#   u'12/1/10 9:58',
#   u'3.37',
#   u'16029',
#   u'United Kingdom'],
#  [u'536387',
#   u'22779',
#   u'WOODEN OWLS LIGHT GARLAND ',
#   u'192',
#   u'12/1/10 9:58',
#   u'3.37',
#   u'16029',
#   u'United Kingdom'],
#  [u'536387',
#   u'22466',
#   u'FAIRY TALE COTTAGE NIGHTLIGHT',
#   u'432',
#   u'12/1/10 9:58',
#   u'1.45',
#   u'16029',
#   u'United Kingdom'],
#  [u'536387',
#   u'21731',
#   u'RED TOADSTOOL LED NIGHT LIGHT',
#   u'432',
#   u'12/1/10 9:58',
#   u'1.25',
#   u'16029',
#   u'United Kingdom'],
#  [u'536388',
#   u'21754',
#   u'HOME BUILDING BLOCK WORD',
#   u'3',
#   u'12/1/10 9:59',
#   u'5.95',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'21755',
#   u'LOVE BUILDING BLOCK WORD',
#   u'3',
#   u'12/1/10 9:59',
#   u'5.95',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'21523',
#   u'DOORMAT FANCY FONT HOME SWEET HOME',
#   u'2',
#   u'12/1/10 9:59',
#   u'7.95',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'21363',
#   u'HOME SMALL WOOD LETTERS',
#   u'3',
#   u'12/1/10 9:59',
#   u'4.95',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'21411',
#   u'GINGHAM HEART  DOORSTOP RED',
#   u'3',
#   u'12/1/10 9:59',
#   u'4.25',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22318',
#   u'FIVE HEART HANGING DECORATION',
#   u'6',
#   u'12/1/10 9:59',
#   u'2.95',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22464',
#   u'HANGING METAL HEART LANTERN',
#   u'12',
#   u'12/1/10 9:59',
#   u'1.65',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22915',
#   u'ASSORTED BOTTLE TOP  MAGNETS ',
#   u'12',
#   u'12/1/10 9:59',
#   u'0.42',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22922',
#   u'FRIDGE MAGNETS US DINER ASSORTED',
#   u'12',
#   u'12/1/10 9:59',
#   u'0.85',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22969',
#   u'HOMEMADE JAM SCENTED CANDLES',
#   u'12',
#   u'12/1/10 9:59',
#   u'1.45',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22923',
#   u'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   u'12',
#   u'12/1/10 9:59',
#   u'0.85',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'21115',
#   u'ROSE CARAVAN DOORSTOP',
#   u'4',
#   u'12/1/10 9:59',
#   u'6.75',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22469',
#   u'HEART OF WICKER SMALL',
#   u'12',
#   u'12/1/10 9:59',
#   u'1.65',
#   u'16250',
#   u'United Kingdom'],
#  [u'536388',
#   u'22242',
#   u'5 HOOK HANGER MAGIC TOADSTOOL',
#   u'12',
#   u'12/1/10 9:59',
#   u'1.65',
#   u'16250',
#   u'United Kingdom'],
#  [u'536389',
#   u'22941',
#   u'CHRISTMAS LIGHTS 10 REINDEER',
#   u'6',
#   u'12/1/10 10:03',
#   u'8.5',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'21622',
#   u'VINTAGE UNION JACK CUSHION COVER',
#   u'8',
#   u'12/1/10 10:03',
#   u'4.95',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'21791',
#   u'VINTAGE HEADS AND TAILS CARD GAME ',
#   u'12',
#   u'12/1/10 10:03',
#   u'1.25',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'35004C',
#   u'SET OF 3 COLOURED  FLYING DUCKS',
#   u'6',
#   u'12/1/10 10:03',
#   u'5.45',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'35004G',
#   u'SET OF 3 GOLD FLYING DUCKS',
#   u'4',
#   u'12/1/10 10:03',
#   u'6.35',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'85014B',
#   u'RED RETROSPOT UMBRELLA',
#   u'6',
#   u'12/1/10 10:03',
#   u'5.95',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'85014A',
#   u'BLACK/BLUE POLKADOT UMBRELLA',
#   u'3',
#   u'12/1/10 10:03',
#   u'5.95',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22193',
#   u'RED DINER WALL CLOCK',
#   u'2',
#   u'12/1/10 10:03',
#   u'8.5',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22726',
#   u'ALARM CLOCK BAKELIKE GREEN',
#   u'4',
#   u'12/1/10 10:03',
#   u'3.75',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22727',
#   u'ALARM CLOCK BAKELIKE RED ',
#   u'4',
#   u'12/1/10 10:03',
#   u'3.75',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22192',
#   u'BLUE DINER WALL CLOCK',
#   u'2',
#   u'12/1/10 10:03',
#   u'8.5',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22191',
#   u'IVORY DINER WALL CLOCK',
#   u'2',
#   u'12/1/10 10:03',
#   u'8.5',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22195',
#   u'LARGE HEART MEASURING SPOONS',
#   u'24',
#   u'12/1/10 10:03',
#   u'1.65',
#   u'12431',
#   u'Australia'],
#  [u'536389',
#   u'22196',
#   u'SMALL HEART MEASURING SPOONS',
#   u'24',
#   u'12/1/10 10:03',
#   u'0.85',
#   u'12431',
#   u'Australia'],
#  [u'536390',
#   u'22941',
#   u'CHRISTMAS LIGHTS 10 REINDEER',
#   u'2',
#   u'12/1/10 10:19',
#   u'8.5',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22960',
#   u'JAM MAKING SET WITH JARS',
#   u'12',
#   u'12/1/10 10:19',
#   u'3.75',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22961',
#   u'JAM MAKING SET PRINTED',
#   u'12',
#   u'12/1/10 10:19',
#   u'1.45',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22962',
#   u'JAM JAR WITH PINK LID',
#   u'48',
#   u'12/1/10 10:19',
#   u'0.72',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22963',
#   u'JAM JAR WITH GREEN LID',
#   u'48',
#   u'12/1/10 10:19',
#   u'0.72',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22968',
#   u'ROSE COTTAGE KEEPSAKE BOX ',
#   u'8',
#   u'12/1/10 10:19',
#   u'8.5',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'84970S',
#   u'HANGING HEART ZINC T-LIGHT HOLDER',
#   u'144',
#   u'12/1/10 10:19',
#   u'0.64',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22910',
#   u'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   u'40',
#   u'12/1/10 10:19',
#   u'2.55',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'20668',
#   u'DISCO BALL CHRISTMAS DECORATION',
#   u'288',
#   u'12/1/10 10:19',
#   u'0.1',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'64',
#   u'12/1/10 10:19',
#   u'2.55',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22197',
#   u'SMALL POPCORN HOLDER',
#   u'100',
#   u'12/1/10 10:19',
#   u'0.72',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22198',
#   u'LARGE POPCORN HOLDER ',
#   u'50',
#   u'12/1/10 10:19',
#   u'1.45',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21533',
#   u'RETROSPOT LARGE MILK JUG',
#   u'12',
#   u'12/1/10 10:19',
#   u'4.25',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21080',
#   u'SET/20 RED RETROSPOT PAPER NAPKINS ',
#   u'96',
#   u'12/1/10 10:19',
#   u'0.64',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21094',
#   u'SET/6 RED SPOTTY PAPER PLATES',
#   u'96',
#   u'12/1/10 10:19',
#   u'0.64',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21086',
#   u'SET/6 RED SPOTTY PAPER CUPS',
#   u'48',
#   u'12/1/10 10:19',
#   u'0.65',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21786',
#   u'POLKADOT RAIN HAT ',
#   u'144',
#   u'12/1/10 10:19',
#   u'0.32',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22654',
#   u'DELUXE SEWING KIT ',
#   u'40',
#   u'12/1/10 10:19',
#   u'4.95',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'21485',
#   u'RETROSPOT HEART HOT WATER BOTTLE',
#   u'24',
#   u'12/1/10 10:19',
#   u'4.25',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'84029G',
#   u'KNITTED UNION FLAG HOT WATER BOTTLE',
#   u'24',
#   u'12/1/10 10:19',
#   u'3.39',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'84030E',
#   u'ENGLISH ROSE HOT WATER BOTTLE',
#   u'24',
#   u'12/1/10 10:19',
#   u'3.75',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22174',
#   u'PHOTO CUBE',
#   u'48',
#   u'12/1/10 10:19',
#   u'1.48',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'22969',
#   u'HOMEMADE JAM SCENTED CANDLES',
#   u'96',
#   u'12/1/10 10:19',
#   u'1.25',
#   u'17511',
#   u'United Kingdom'],
#  [u'536390',
#   u'85099B',
#   u'JUMBO BAG RED RETROSPOT',
#   u'100',
#   u'12/1/10 10:19',
#   u'1.65',
#   u'17511',
#   u'United Kingdom'],
#  [u'536392',
#   u'22150',
#   u'3 STRIPEY MICE FELTCRAFT',
#   u'6',
#   u'12/1/10 10:29',
#   u'1.95',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22619',
#   u'SET OF 6 SOLDIER SKITTLES',
#   u'4',
#   u'12/1/10 10:29',
#   u'3.75',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'21891',
#   u'TRADITIONAL WOODEN SKIPPING ROPE',
#   u'12',
#   u'12/1/10 10:29',
#   u'1.25',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'21889',
#   u'WOODEN BOX OF DOMINOES',
#   u'12',
#   u'12/1/10 10:29',
#   u'1.25',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22827',
#   u'RUSTIC  SEVENTEEN DRAWER SIDEBOARD',
#   u'1',
#   u'12/1/10 10:29',
#   u'165',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22127',
#   u'PARTY CONES CARNIVAL ASSORTED',
#   u'12',
#   u'12/1/10 10:29',
#   u'1.25',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22128',
#   u'PARTY CONES CANDY ASSORTED',
#   u'12',
#   u'12/1/10 10:29',
#   u'1.25',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22502',
#   u'PICNIC BASKET WICKER SMALL',
#   u'4',
#   u'12/1/10 10:29',
#   u'5.95',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'84879',
#   u'ASSORTED COLOUR BIRD ORNAMENT',
#   u'16',
#   u'12/1/10 10:29',
#   u'1.69',
#   u'13705',
#   u'United Kingdom'],
#  [u'536392',
#   u'22338',
#   u'STAR DECORATION PAINTED ZINC ',
#   u'24',
#   u'12/1/10 10:29',
#   u'0.65',
#   u'13705',
#   u'United Kingdom'],
#  [u'536393',
#   u'22180',
#   u'RETROSPOT LAMP',
#   u'8',
#   u'12/1/10 10:37',
#   u'9.95',
#   u'13747',
#   u'United Kingdom'],
#  [u'536394',
#   u'21506',
#   u'FANCY FONT BIRTHDAY CARD ',
#   u'24',
#   u'12/1/10 10:39',
#   u'0.42',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'96',
#   u'12/1/10 10:39',
#   u'1.85',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22866',
#   u'HAND WARMER SCOTTY DOG DESIGN',
#   u'96',
#   u'12/1/10 10:39',
#   u'1.85',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22865',
#   u'HAND WARMER OWL DESIGN',
#   u'96',
#   u'12/1/10 10:39',
#   u'1.85',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22632',
#   u'HAND WARMER RED RETROSPOT',
#   u'96',
#   u'12/1/10 10:39',
#   u'1.85',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'21485',
#   u'RETROSPOT HEART HOT WATER BOTTLE',
#   u'12',
#   u'12/1/10 10:39',
#   u'4.95',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22349',
#   u'DOG BOWL CHASING BALL DESIGN',
#   u'12',
#   u'12/1/10 10:39',
#   u'3.75',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22558',
#   u'CLOTHES PEGS RETROSPOT PACK 24 ',
#   u'48',
#   u'12/1/10 10:39',
#   u'1.25',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'85152',
#   u'HAND OVER THE CHOCOLATE   SIGN ',
#   u'12',
#   u'12/1/10 10:39',
#   u'2.1',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'32',
#   u'12/1/10 10:39',
#   u'2.55',
#   u'13408',
#   u'United Kingdom'],
#  [u'536394',
#   u'22652',
#   u'TRAVEL SEWING KIT',
#   u'20',
#   u'12/1/10 10:39',
#   u'1.65',
#   u'13408',
#   u'United Kingdom'],
#  [u'536395',
#   u'22188',
#   u'BLACK HEART CARD HOLDER',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.95',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'84879',
#   u'ASSORTED COLOUR BIRD ORNAMENT',
#   u'32',
#   u'12/1/10 10:47',
#   u'1.69',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'21977',
#   u'PACK OF 60 PINK PAISLEY CAKE CASES',
#   u'24',
#   u'12/1/10 10:47',
#   u'0.55',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'84991',
#   u'60 TEATIME FAIRY CAKE CASES',
#   u'24',
#   u'12/1/10 10:47',
#   u'0.55',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'21212',
#   u'PACK OF 72 RETROSPOT CAKE CASES',
#   u'24',
#   u'12/1/10 10:47',
#   u'0.55',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'21484',
#   u'CHICK GREY HOT WATER BOTTLE',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.45',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'21314',
#   u'SMALL GLASS HEART TRINKET POT',
#   u'8',
#   u'12/1/10 10:47',
#   u'2.1',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22730',
#   u'ALARM CLOCK BAKELIKE IVORY',
#   u'4',
#   u'12/1/10 10:47',
#   u'3.75',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22727',
#   u'ALARM CLOCK BAKELIKE RED ',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.75',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22729',
#   u'ALARM CLOCK BAKELIKE ORANGE',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.75',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22726',
#   u'ALARM CLOCK BAKELIKE GREEN',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.75',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22114',
#   u'HOT WATER BOTTLE TEA AND SYMPATHY',
#   u'8',
#   u'12/1/10 10:47',
#   u'3.95',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22867',
#   u'HAND WARMER BIRD DESIGN',
#   u'48',
#   u'12/1/10 10:47',
#   u'2.1',
#   u'13767',
#   u'United Kingdom'],
#  [u'536395',
#   u'22866',
#   u'HAND WARMER SCOTTY DOG DESIGN',
#   u'48',
#   u'12/1/10 10:47',
#   u'2.1',
#   u'13767',
#   u'United Kingdom'],
#  [u'536396',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 10:51',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'71053',
#   u'WHITE METAL LANTERN',
#   u'6',
#   u'12/1/10 10:51',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'84406B',
#   u'CREAM CUPID HEARTS COAT HANGER',
#   u'8',
#   u'12/1/10 10:51',
#   u'2.75',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'15056BL',
#   u'EDWARDIAN PARASOL BLACK',
#   u'6',
#   u'12/1/10 10:51',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'20679',
#   u'EDWARDIAN PARASOL RED',
#   u'6',
#   u'12/1/10 10:51',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'37370',
#   u'RETRO COFFEE MUGS ASSORTED',
#   u'6',
#   u'12/1/10 10:51',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'21871',
#   u'SAVE THE PLANET MUG',
#   u'6',
#   u'12/1/10 10:51',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'21071',
#   u'VINTAGE BILLBOARD DRINK ME MUG',
#   u'6',
#   u'12/1/10 10:51',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'21068',
#   u'VINTAGE BILLBOARD LOVE/HATE MUG',
#   u'6',
#   u'12/1/10 10:51',
#   u'1.06',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'82483',
#   u'WOOD 2 DRAWER CABINET WHITE FINISH',
#   u'2',
#   u'12/1/10 10:51',
#   u'4.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'82486',
#   u'WOOD S/3 CABINET ANT WHITE FINISH',
#   u'4',
#   u'12/1/10 10:51',
#   u'6.95',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'82482',
#   u'WOODEN PICTURE FRAME WHITE FINISH',
#   u'6',
#   u'12/1/10 10:51',
#   u'2.1',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'82494L',
#   u'WOODEN FRAME ANTIQUE WHITE ',
#   u'12',
#   u'12/1/10 10:51',
#   u'2.55',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'84029G',
#   u'KNITTED UNION FLAG HOT WATER BOTTLE',
#   u'6',
#   u'12/1/10 10:51',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'84029E',
#   u'RED WOOLLY HOTTIE WHITE HEART.',
#   u'6',
#   u'12/1/10 10:51',
#   u'3.39',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'22752',
#   u'SET 7 BABUSHKA NESTING BOXES',
#   u'2',
#   u'12/1/10 10:51',
#   u'7.65',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'22803',
#   u'IVORY EMBROIDERED QUILT ',
#   u'2',
#   u'12/1/10 10:51',
#   u'35.75',
#   u'17850',
#   u'United Kingdom'],
#  [u'536396',
#   u'21730',
#   u'GLASS STAR FROSTED T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 10:51',
#   u'4.25',
#   u'17850',
#   u'United Kingdom'],
#  [u'536397',
#   u'35004B',
#   u'SET OF 3 BLACK FLYING DUCKS',
#   u'12',
#   u'12/1/10 10:51',
#   u'4.65',
#   u'17924',
#   u'United Kingdom'],
#  [u'536397',
#   u'35004C',
#   u'SET OF 3 COLOURED  FLYING DUCKS',
#   u'48',
#   u'12/1/10 10:51',
#   u'4.65',
#   u'17924',
#   u'United Kingdom'],
#  [u'536398',
#   u'21980',
#   u'PACK OF 12 RED RETROSPOT TISSUES ',
#   u'24',
#   u'12/1/10 10:52',
#   u'0.29',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'21844',
#   u'RED RETROSPOT MUG',
#   u'6',
#   u'12/1/10 10:52',
#   u'2.95',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22468',
#   u'BABUSHKA LIGHTS STRING OF 10',
#   u'4',
#   u'12/1/10 10:52',
#   u'6.75',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22637',
#   u'PIGGY BANK RETROSPOT ',
#   u'8',
#   u'12/1/10 10:52',
#   u'2.55',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22752',
#   u'SET 7 BABUSHKA NESTING BOXES',
#   u'6',
#   u'12/1/10 10:52',
#   u'8.5',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'48185',
#   u'DOORMAT FAIRY CAKE',
#   u'2',
#   u'12/1/10 10:52',
#   u'7.95',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22632',
#   u'HAND WARMER RED RETROSPOT',
#   u'12',
#   u'12/1/10 10:52',
#   u'2.1',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22866',
#   u'HAND WARMER SCOTTY DOG DESIGN',
#   u'12',
#   u'12/1/10 10:52',
#   u'2.1',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22865',
#   u'HAND WARMER OWL DESIGN',
#   u'12',
#   u'12/1/10 10:52',
#   u'2.1',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'21232',
#   u'STRAWBERRY CERAMIC TRINKET BOX',
#   u'12',
#   u'12/1/10 10:52',
#   u'1.25',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22064',
#   u'PINK DOUGHNUT TRINKET POT ',
#   u'12',
#   u'12/1/10 10:52',
#   u'1.65',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22449',
#   u'SILK PURSE BABUSHKA PINK',
#   u'6',
#   u'12/1/10 10:52',
#   u'3.35',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22114',
#   u'HOT WATER BOTTLE TEA AND SYMPATHY',
#   u'4',
#   u'12/1/10 10:52',
#   u'3.95',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22835',
#   u'HOT WATER BOTTLE I AM SO POORLY',
#   u'8',
#   u'12/1/10 10:52',
#   u'4.65',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22112',
#   u'CHOCOLATE HOT WATER BOTTLE',
#   u'9',
#   u'12/1/10 10:52',
#   u'4.95',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'21479',
#   u'WHITE SKULL HOT WATER BOTTLE ',
#   u'4',
#   u'12/1/10 10:52',
#   u'3.75',
#   u'13448',
#   u'United Kingdom'],
#  [u'536398',
#   u'22111',
#   u'SCOTTIE DOG HOT WATER BOTTLE',
#   u'9',
#   u'12/1/10 10:52',
#   u'4.95',
#   u'13448',
#   u'United Kingdom'],
#  [u'536399',
#   u'22632',
#   u'HAND WARMER RED POLKA DOT',
#   u'6',
#   u'12/1/10 10:52',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536399',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'6',
#   u'12/1/10 10:52',
#   u'1.85',
#   u'17850',
#   u'United Kingdom'],
#  [u'536400',
#   u'22969',
#   u'HOMEMADE JAM SCENTED CANDLES',
#   u'12',
#   u'12/1/10 10:53',
#   u'1.45',
#   u'13448',
#   u'United Kingdom'],
#  [u'536401',
#   u'22110',
#   u'BIRD HOUSE HOT WATER BOTTLE',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22098',
#   u'BOUDOIR SQUARE TISSUE BOX',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22100',
#   u'SKULLS SQUARE TISSUE BOX',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22766',
#   u'PHOTO FRAME CORNICE',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22451',
#   u'SILK PURSE BABUSHKA RED',
#   u'1',
#   u'12/1/10 11:21',
#   u'3.35',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22549',
#   u'PICTURE DOMINOES',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.45',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84744',
#   u'S/6 SEW ON CROCHET FLOWERS',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'85049E',
#   u'SCANDINAVIAN REDS RIBBONS',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21328',
#   u'BALLOONS  WRITING SET ',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22961',
#   u'JAM MAKING SET PRINTED',
#   u'4',
#   u'12/1/10 11:21',
#   u'1.45',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'17091A',
#   u'LAVENDER INCENSE IN TIN',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22473',
#   u'TV DINNER TRAY VINTAGE PAISLEY',
#   u'1',
#   u'12/1/10 11:21',
#   u'4.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84509A',
#   u'SET OF 4 ENGLISH ROSE PLACEMATS',
#   u'2',
#   u'12/1/10 11:21',
#   u'3.75',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84510A',
#   u'SET OF 4 ENGLISH ROSE COASTERS',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22767',
#   u'TRIPLE PHOTO FRAME CORNICE ',
#   u'2',
#   u'12/1/10 11:21',
#   u'9.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22768',
#   u'FAMILY PHOTO FRAME CORNICE',
#   u'1',
#   u'12/1/10 11:21',
#   u'9.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21463',
#   u'MIRRORED DISCO BALL ',
#   u'1',
#   u'12/1/10 11:21',
#   u'5.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21464',
#   u'DISCO BALL ROTATOR BATTERY OPERATED',
#   u'1',
#   u'12/1/10 11:21',
#   u'4.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20820',
#   u'SILVER LOOKING MIRROR',
#   u'3',
#   u'12/1/10 11:21',
#   u'4.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'85150',
#   u'LADIES & GENTLEMEN METAL SIGN',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22117',
#   u'METAL SIGN HER DINNER IS SERVED ',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21169',
#   u"YOU'RE CONFUSING ME METAL SIGN ",
#   u'2',
#   u'12/1/10 11:21',
#   u'1.69',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'48129',
#   u'DOORMAT TOPIARY',
#   u'1',
#   u'12/1/10 11:21',
#   u'7.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'82580',
#   u'BATHROOM METAL SIGN',
#   u'1',
#   u'12/1/10 11:21',
#   u'0.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'82578',
#   u'KITCHEN METAL SIGN',
#   u'1',
#   u'12/1/10 11:21',
#   u'0.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'82581',
#   u'TOILET METAL SIGN',
#   u'2',
#   u'12/1/10 11:21',
#   u'0.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22413',
#   u'METAL SIGN TAKE IT OR LEAVE IT ',
#   u'4',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21907',
#   u"I'M ON HOLIDAY METAL SIGN",
#   u'2',
#   u'12/1/10 11:21',
#   u'2.1',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22441',
#   u'GROW YOUR OWN BASIL IN ENAMEL MUG',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.1',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21122',
#   u'SET/10 PINK POLKADOT PARTY CANDLES',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22851',
#   u'SET 20 NAPKINS FAIRY CAKES DESIGN ',
#   u'1',
#   u'12/1/10 11:21',
#   u'0.85',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84991',
#   u'60 TEATIME FAIRY CAKE CASES',
#   u'3',
#   u'12/1/10 11:21',
#   u'0.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22810',
#   u'SET OF 6 T-LIGHTS SNOWMEN',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22809',
#   u'SET OF 6 T-LIGHTS SANTA',
#   u'1',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22435',
#   u'SET OF 9 HEART SHAPED BALLOONS',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20966',
#   u'SANDWICH BATH SPONGE',
#   u'3',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20963',
#   u'APPLE BATH SPONGE',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20961',
#   u'STRAWBERRY BATH SPONGE ',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22068',
#   u'BLACK PIRATE TREASURE CHEST',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21743',
#   u'STAR PORTABLE TABLE LIGHT ',
#   u'2',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21744',
#   u'SNOWFLAKE PORTABLE TABLE LIGHT ',
#   u'2',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84709B',
#   u'PINK OVAL JEWELLED MIRROR',
#   u'1',
#   u'12/1/10 11:21',
#   u'5.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21592',
#   u'RETROSPOT CIGAR BOX MATCHES ',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.25',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21587',
#   u'COSY HOUR GIANT TUBE MATCHES',
#   u'2',
#   u'12/1/10 11:21',
#   u'2.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20992',
#   u'JAZZ HEARTS PURSE NOTEBOOK',
#   u'9',
#   u'12/1/10 11:21',
#   u'0.85',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22662',
#   u'LUNCH BAG DOLLY GIRL DESIGN',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'4',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22804',
#   u'CANDLEHOLDER PINK HANGING HEART',
#   u'3',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'82483',
#   u'WOOD 2 DRAWER CABINET WHITE FINISH',
#   u'1',
#   u'12/1/10 11:21',
#   u'5.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20749',
#   u'ASSORTED COLOUR MINI CASES',
#   u'1',
#   u'12/1/10 11:21',
#   u'7.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20725',
#   u'LUNCH BAG RED RETROSPOT',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22382',
#   u'LUNCH BAG SPACEBOY DESIGN ',
#   u'2',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'20726',
#   u'LUNCH BAG WOODLAND',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22384',
#   u'LUNCH BAG PINK POLKADOT',
#   u'1',
#   u'12/1/10 11:21',
#   u'1.65',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'22467',
#   u'GUMBALL COAT RACK',
#   u'5',
#   u'12/1/10 11:21',
#   u'2.55',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84625C',
#   u'BLUE NEW BAROQUE CANDLESTICK CANDLE',
#   u'3',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'84625A',
#   u'PINK NEW BAROQUECANDLESTICK CANDLE',
#   u'3',
#   u'12/1/10 11:21',
#   u'2.95',
#   u'15862',
#   u'United Kingdom'],
#  [u'536401',
#   u'21108',
# ...
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'84347',
#   u'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.55',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21577',
#   u'SAVE THE PLANET COTTON TOTE BAG',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22909',
#   u'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   u'1',
#   u'12/1/10 12:31',
#   u'0.85',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22087',
#   u'PAPER BUNTING WHITE LACE',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.95',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22651',
#   u'GENTLEMAN SHIRT REPAIR KIT ',
#   u'2',
#   u'12/1/10 12:31',
#   u'0.85',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22713',
#   u'CARD I LOVE LONDON ',
#   u'12',
#   u'12/1/10 12:31',
#   u'0.42',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22910',
#   u'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.95',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21370',
#   u'MIRRORED WALL ART FOXY',
#   u'2',
#   u'12/1/10 12:31',
#   u'6.35',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21367',
#   u'MIRRORED WALL ART GENTS',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.55',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22376',
#   u'AIRLINE BAG VINTAGE JET SET WHITE',
#   u'1',
#   u'12/1/10 12:31',
#   u'4.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22961',
#   u'JAM MAKING SET PRINTED',
#   u'1',
#   u'12/1/10 12:31',
#   u'1.45',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21895',
#   u"POTTING SHED SOW 'N' GROW SET",
#   u'1',
#   u'12/1/10 12:31',
#   u'4.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22468',
#   u'BABUSHKA LIGHTS STRING OF 10',
#   u'1',
#   u'12/1/10 12:31',
#   u'6.75',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21034',
#   u'REX CASH+CARRY JUMBO SHOPPER',
#   u'1',
#   u'12/1/10 12:31',
#   u'0.95',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22372',
#   u'AIRLINE BAG VINTAGE WORLD CHAMPION ',
#   u'1',
#   u'12/1/10 12:31',
#   u'4.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22867',
#   u'HAND WARMER BIRD DESIGN',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.1',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22144',
#   u'CHRISTMAS CRAFT LITTLE FRIENDS',
#   u'1',
#   u'12/1/10 12:31',
#   u'2.1',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21190',
#   u'PINK HEARTS PAPER GARLAND',
#   u'1',
#   u'12/1/10 12:31',
#   u'1.65',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'21894',
#   u'POTTING SHED SEED ENVELOPES',
#   u'3',
#   u'12/1/10 12:31',
#   u'1.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'70007',
#   u'HI TEC ALPINE HAND WARMER',
#   u'3',
#   u'12/1/10 12:31',
#   u'1.65',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22940',
#   u'FELTCRAFT CHRISTMAS FAIRY',
#   u'1',
#   u'12/1/10 12:31',
#   u'4.25',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'70007',
#   u'HI TEC ALPINE HAND WARMER',
#   u'1',
#   u'12/1/10 12:31',
#   u'1.65',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'84347',
#   u'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   u'3',
#   u'12/1/10 12:31',
#   u'2.55',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22150',
#   u'3 STRIPEY MICE FELTCRAFT',
#   u'1',
#   u'12/1/10 12:31',
#   u'1.95',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22149',
#   u'FELTCRAFT 6 FLOWER FRIENDS',
#   u'2',
#   u'12/1/10 12:31',
#   u'2.1',
#   u'17897',
#   u'United Kingdom'],
#  [u'536488',
#   u'22144',
#   u'CHRISTMAS CRAFT LITTLE FRIENDS',
#   u'2',
#   u'12/1/10 12:31',
#   u'2.1',
#   u'17897',
#   u'United Kingdom'],
#  [u'536500',
#   u'21622',
#   u'VINTAGE UNION JACK CUSHION COVER',
#   u'10',
#   u'12/1/10 12:35',
#   u'4.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'46000M',
#   u'POLYESTER FILLER PAD 45x45cm',
#   u'10',
#   u'12/1/10 12:35',
#   u'1.55',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22630',
#   u'DOLLY GIRL LUNCH BOX',
#   u'2',
#   u'12/1/10 12:35',
#   u'1.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22616',
#   u'PACK OF 12 LONDON TISSUES ',
#   u'12',
#   u'12/1/10 12:35',
#   u'0.29',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22712',
#   u'CARD DOLLY GIRL ',
#   u'12',
#   u'12/1/10 12:35',
#   u'0.42',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22983',
#   u'CARD BILLBOARD FONT',
#   u'12',
#   u'12/1/10 12:35',
#   u'0.42',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22024',
#   u'RAINY LADIES BIRTHDAY CARD',
#   u'12',
#   u'12/1/10 12:35',
#   u'0.42',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22113',
#   u'GREY HEART HOT WATER BOTTLE',
#   u'3',
#   u'12/1/10 12:35',
#   u'3.75',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'84029E',
#   u'RED WOOLLY HOTTIE WHITE HEART.',
#   u'2',
#   u'12/1/10 12:35',
#   u'3.75',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'21488',
#   u'RED WHITE SCARF  HOT WATER BOTTLE',
#   u'2',
#   u'12/1/10 12:35',
#   u'3.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22900',
#   u' SET 2 TEA TOWELS I LOVE LONDON ',
#   u'7',
#   u'12/1/10 12:35',
#   u'2.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'22895',
#   u'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   u'3',
#   u'12/1/10 12:35',
#   u'2.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'21035',
#   u'SET/2 RED RETROSPOT TEA TOWELS ',
#   u'3',
#   u'12/1/10 12:35',
#   u'2.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'21755',
#   u'LOVE BUILDING BLOCK WORD',
#   u'6',
#   u'12/1/10 12:35',
#   u'5.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536500',
#   u'21754',
#   u'HOME BUILDING BLOCK WORD',
#   u'6',
#   u'12/1/10 12:35',
#   u'5.95',
#   u'17377',
#   u'United Kingdom'],
#  [u'536502',
#   u'84879',
#   u'ASSORTED COLOUR BIRD ORNAMENT',
#   u'16',
#   u'12/1/10 12:36',
#   u'1.69',
#   u'16552',
#   u'United Kingdom'],
#  [u'536502',
#   u'22784',
#   u'LANTERN CREAM GAZEBO ',
#   u'3',
#   u'12/1/10 12:36',
#   u'4.95',
#   u'16552',
#   u'United Kingdom'],
#  [u'536502',
#   u'21441',
#   u'BLUE BIRDHOUSE DECORATION',
#   u'12',
#   u'12/1/10 12:36',
#   u'0.85',
#   u'16552',
#   u'United Kingdom'],
#  [u'536502',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'6',
#   u'12/1/10 12:36',
#   u'2.95',
#   u'16552',
#   u'United Kingdom'],
#  [u'536502',
#   u'22423',
#   u'REGENCY CAKESTAND 3 TIER',
#   u'2',
#   u'12/1/10 12:36',
#   u'12.75',
#   u'16552',
#   u'United Kingdom'],
#  [u'536508',
#   u'84947',
#   u'ANTIQUE SILVER TEA GLASS ENGRAVED',
#   u'72',
#   u'12/1/10 12:38',
#   u'1.06',
#   u'17181',
#   u'United Kingdom'],
#  [u'536508',
#   u'21326',
#   u'AGED GLASS SILVER T-LIGHT HOLDER',
#   u'144',
#   u'12/1/10 12:38',
#   u'0.55',
#   u'17181',
#   u'United Kingdom'],
#  [u'536514',
#   u'22865',
#   u'HAND WARMER OWL DESIGN',
#   u'36',
#   u'12/1/10 12:40',
#   u'2.1',
#   u'17951',
#   u'United Kingdom'],
#  [u'536514',
#   u'22485',
#   u'SET OF 2 WOODEN MARKET CRATES',
#   u'4',
#   u'12/1/10 12:40',
#   u'12.75',
#   u'17951',
#   u'United Kingdom'],
#  [u'536514',
#   u'22807',
#   u'SET OF 6 T-LIGHTS TOADSTOOLS',
#   u'6',
#   u'12/1/10 12:40',
#   u'2.95',
#   u'17951',
#   u'United Kingdom'],
#  [u'536514',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'36',
#   u'12/1/10 12:40',
#   u'2.1',
#   u'17951',
#   u'United Kingdom'],
#  [u'536514',
#   u'22866',
#   u'HAND WARMER SCOTTY DOG DESIGN',
#   u'36',
#   u'12/1/10 12:40',
#   u'2.1',
#   u'17951',
#   u'United Kingdom'],
#  [u'536520',
#   u'21794',
#   u'CLASSIC FRENCH STYLE BASKET NATURAL',
#   u'1',
#   u'12/1/10 12:43',
#   u'6.75',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'20707',
#   u'CRAZY DAISY HEART DECORATION',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21175',
#   u'GIN + TONIC DIET METAL SIGN',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22926',
#   u'IVORY GIANT GARDEN THERMOMETER',
#   u'1',
#   u'12/1/10 12:43',
#   u'5.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22588',
#   u'CARD HOLDER GINGHAM HEART',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21292',
#   u'SMALL STRIPES CHOCOLATE GIFT BAG ',
#   u'16',
#   u'12/1/10 12:43',
#   u'0.85',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21890',
#   u'S/6 WOODEN SKITTLES IN COTTON BAG',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22632',
#   u'HAND WARMER RED RETROSPOT',
#   u'4',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22633',
#   u'HAND WARMER UNION JACK',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22670',
#   u'FRENCH WC SIGN BLUE METAL',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21867',
#   u'PINK UNION JACK  LUGGAGE TAG',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22760',
#   u'TRAY BREAKFAST IN BED',
#   u'1',
#   u'12/1/10 12:43',
#   u'12.75',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22107',
#   u'PIZZA PLATE IN BOX',
#   u'2',
#   u'12/1/10 12:43',
#   u'3.75',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22470',
#   u'HEART OF WICKER LARGE',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21486',
#   u'PINK HEART DOTS HOT WATER BOTTLE',
#   u'1',
#   u'12/1/10 12:43',
#   u'3.75',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22151',
#   u'PLACE SETTING WHITE HEART',
#   u'14',
#   u'12/1/10 12:43',
#   u'0.42',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22643',
#   u'SET OF 4 NAPKIN CHARMS LEAVES   ',
#   u'4',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22642',
#   u'SET OF 4 NAPKIN CHARMS STARS   ',
#   u'4',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22604',
#   u'SET OF 4 NAPKIN CHARMS CUTLERY',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22099',
#   u'CARAVAN SQUARE TISSUE BOX',
#   u'2',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22553',
#   u'PLASTERS IN TIN SKULLS',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22551',
#   u'PLASTERS IN TIN SPACEBOY',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22653',
#   u'BUTTON BOX ',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22557',
#   u'PLASTERS IN TIN VINTAGE PAISLEY ',
#   u'2',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22906',
#   u'12 MESSAGE CARDS WITH ENVELOPES',
#   u'6',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22754',
#   u'SMALL RED BABUSHKA NOTEBOOK ',
#   u'1',
#   u'12/1/10 12:43',
#   u'0.85',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22938',
#   u'CUPCAKE LACE PAPER SET 6',
#   u'5',
#   u'12/1/10 12:43',
#   u'1.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22812',
#   u'PACK 3 BOXES CHRISTMAS PANNETONE',
#   u'3',
#   u'12/1/10 12:43',
#   u'1.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22919',
#   u'HERB MARKER MINT',
#   u'2',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22917',
#   u'HERB MARKER ROSEMARY',
#   u'1',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22920',
#   u'HERB MARKER BASIL',
#   u'3',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22921',
#   u'HERB MARKER CHIVES ',
#   u'2',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22918',
#   u'HERB MARKER PARSLEY',
#   u'2',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22916',
#   u'HERB MARKER THYME',
#   u'1',
#   u'12/1/10 12:43',
#   u'0.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'85123A',
#   u'WHITE HANGING HEART T-LIGHT HOLDER',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22575',
#   u'METAL MERRY CHRISTMAS WREATH',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21804',
#   u'WHITE CHRISTMAS GARLAND STARS TREES',
#   u'3',
#   u'12/1/10 12:43',
#   u'3.75',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21584',
#   u'RETROSPOT SMALL TUBE MATCHES',
#   u'12',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21588',
#   u'RETROSPOT GIANT TUBE MATCHES',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22152',
#   u'PLACE SETTING WHITE STAR',
#   u'12',
#   u'12/1/10 12:43',
#   u'0.42',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22441',
#   u'GROW YOUR OWN BASIL IN ENAMEL MUG',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22955',
#   u'36 FOIL STAR CAKE CASES ',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22956',
#   u'36 FOIL HEART CAKE CASES',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22582',
#   u'PACK OF 6 SWEETIE GIFT BOXES',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22583',
#   u'PACK OF 6 HANDBAG GIFT BOXES',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22241',
#   u'GARLAND WOODEN HAPPY EASTER',
#   u'2',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22904',
#   u'CALENDAR PAPER CUT DESIGN',
#   u'3',
#   u'12/1/10 12:43',
#   u'2.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22905',
#   u'CALENDAR IN SEASON DESIGN',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22197',
#   u'SMALL POPCORN HOLDER',
#   u'3',
#   u'12/1/10 12:43',
#   u'0.85',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22092',
#   u'BLUE PAISLEY TISSUE BOX',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22469',
#   u'HEART OF WICKER SMALL',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22100',
#   u'SKULLS SQUARE TISSUE BOX',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22096',
#   u'PINK PAISLEY SQUARE TISSUE BOX ',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22583',
#   u'PACK OF 6 HANDBAG GIFT BOXES',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21358',
#   u'TOAST ITS - HAPPY BIRTHDAY',
#   u'2',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21123',
#   u'SET/10 IVORY POLKADOT PARTY CANDLES',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21124',
#   u'SET/10 BLUE POLKADOT PARTY CANDLES',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21122',
#   u'SET/10 PINK POLKADOT PARTY CANDLES',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'84378',
#   u'SET OF 3 HEART COOKIE CUTTERS',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.25',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21985',
#   u'PACK OF 12 HEARTS DESIGN TISSUES ',
#   u'12',
#   u'12/1/10 12:43',
#   u'0.29',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21427',
#   u'SKULLS STORAGE BOX SMALL',
#   u'2',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21034',
#   u'REX CASH+CARRY JUMBO SHOPPER',
#   u'2',
#   u'12/1/10 12:43',
#   u'0.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'21930',
#   u'JUMBO STORAGE BAG SKULLS',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.95',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'20772',
#   u'GARDEN PATH JOURNAL',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.55',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'22469',
#   u'HEART OF WICKER SMALL',
#   u'2',
#   u'12/1/10 12:43',
#   u'1.65',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'71406C',
#   u'BLACK ORANGE SQUEEZER',
#   u'12',
#   u'12/1/10 12:43',
#   u'0.42',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'84985A',
#   u'SET OF 72 GREEN PAPER DOILIES',
#   u'1',
#   u'12/1/10 12:43',
#   u'1.45',
#   u'14729',
#   u'United Kingdom'],
#  [u'536520',
#   u'20754',
#   u'RETROSPOT RED WASHING UP GLOVES',
#   u'1',
#   u'12/1/10 12:43',
#   u'2.1',
#   u'14729',
#   u'United Kingdom'],
#  ...]

# %% [markdown]
# ###  2.3 - Map each line to a SQL Row and create a Dataframe from the result.   Register the Dataframe as an SQL temp table.
# <br>
# Use the following for the Row column names: inv, stockCode, description, quant, invDate, price, custId, country.   inv, stockCode, quant and custId should be integers.
# price is a float.  description and country are strings (the default).
# <br><br>
# Hint: When you replaced non-digit characters using the regular expression above, you replaced them in the context of a test.  You'll have to do it again when creating the stockCode Row value.
# <br><br>
#  <div class="panel-group" id="accordion-23">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-23" href="#collapse1-23">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-23" class="panel-collapse collapse">
#       <div class="panel-body">We haven't used SQLContext or Row in this notebook, so you will have to import them from the pyspark.sql package and then create a <i>SQLContext</i>.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-23" href="#collapse2-23">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-23" class="panel-collapse collapse">
#       <div class="panel-body">You can create a <i>Row</i> using a <i>map()</i>.   For example:<br>
#       example = myRDD.map(lambda x: Row(v1=x[1], v2=int(x[2]), v3=float(x[3]))<br>
#       Note how we set the column names this way.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-23" href="#collapse3-23">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-23" class="panel-collapse collapse">
#       <div class="panel-body">use <i>createDataFrame()</i> in your <i>SQLContext</i>.   Then register the dataframe with <i>registerTempTable()</i></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-23" href="#collapse4-23">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-23" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# from pyspark.sql import SQLContext, Row<br>
# sqlContext = SQLContext(sc)<br>
#
# retailRows = filteredRetailData.map(lambda l: Row(inv=int(l[0]), stockCode=int(re.sub("\D", "", l[1])), description=l[2], quant=int(l[3]), invDate=l[4], price=float(l[5]), custId=int(l[6]), country=l[7]))<br>
#
# retailDf = sqlContext.createDataFrame(retailRows)<br>
# retailDf.registerTempTable("retailPurchases")</div>
#     </div>
#   </div>
# </div>

# %%
from pyspark.sql import SQLContext, Row
sqlContext = SQLContext(sc)

retailRows = filteredRetailData.map(lambda l: Row(inv=int(l[0]), stockCode=int(re.sub("\D", "", l[1])), description=l[2], quant=int(l[3]), invDate=l[4], price=float(l[5]), custId=int(l[6]), country=l[7]))

retailDf = sqlContext.createDataFrame(retailRows)
retailDf.registerTempTable("retailPurchases")

# %% [markdown]
# ### 2.4 - Keep only the data we need (custId, stockCode, and rank)
# <br>
# The Alternating Least Squares algorithm requires three values.   In this case, we're going to use the Customer ID (custId), stock code (stockCode) and a ranking value.   In this situation there is not a ranking value within the data, so we will create one.   We will set a value of 1 to indicate a purchase since these are all actual orders.   Set that value to "purch".
# <br><br>
# After doing the select, group by custId and stockCode.
# <br><br>
#  <div class="panel-group" id="accordion-24">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-24" href="#collapse1-24">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-24" class="panel-collapse collapse">
#       <div class="panel-body">To add a fixed value within a select statement, use something like <i>select x,y,1 as purch from z</i></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-24" href="#collapse2-24">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-24" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>group by</i> statement to group results.  To group by two values, separate them by commas (i.e. <i>group by x,y</i>)</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-24" href="#collapse3-24">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-24" class="panel-collapse collapse">
#       <div class="panel-body">Type:
#
# query = "
# SELECT
#     custId, stockCode, 1 as purch
# FROM
#     retailPurchases
# group
#     by custId, stockCode"<br>
# uniqueCombDf = sqlContext.sql(query)</div>
#     </div>
#   </div>
# </div>

# %%
query = "select custId, stockCode, 1 as purch FROM retailPurchases group by custId, stockCode"
uniqueCombDf = sqlContext.sql(query)
uniqueCombDf.collect()
# Out:
# [Row(custId=12838, stockCode=22941, purch=1),
#  Row(custId=17968, stockCode=22731, purch=1),
#  Row(custId=16210, stockCode=20977, purch=1),
#  Row(custId=17897, stockCode=84558, purch=1),
#  Row(custId=16552, stockCode=85123, purch=1),
#  Row(custId=17905, stockCode=21662, purch=1),
#  Row(custId=13468, stockCode=21231, purch=1),
#  Row(custId=16274, stockCode=21809, purch=1),
#  Row(custId=13090, stockCode=22617, purch=1),
#  Row(custId=16186, stockCode=22865, purch=1),
#  Row(custId=15574, stockCode=22909, purch=1),
#  Row(custId=14031, stockCode=22800, purch=1),
#  Row(custId=18168, stockCode=21531, purch=1),
#  Row(custId=15093, stockCode=21506, purch=1),
#  Row(custId=17967, stockCode=22968, purch=1),
#  Row(custId=17841, stockCode=84030, purch=1),
#  Row(custId=17238, stockCode=22141, purch=1),
#  Row(custId=16033, stockCode=22726, purch=1),
#  Row(custId=18055, stockCode=22112, purch=1),
#  Row(custId=13069, stockCode=22594, purch=1),
#  Row(custId=16931, stockCode=22300, purch=1),
#  Row(custId=14813, stockCode=22866, purch=1),
#  Row(custId=12567, stockCode=22968, purch=1),
#  Row(custId=17059, stockCode=21164, purch=1),
#  Row(custId=12748, stockCode=35471, purch=1),
#  Row(custId=12748, stockCode=22071, purch=1),
#  Row(custId=15880, stockCode=21187, purch=1),
#  Row(custId=12763, stockCode=22716, purch=1),
#  Row(custId=14081, stockCode=20750, purch=1),
#  Row(custId=18219, stockCode=22844, purch=1),
#  Row(custId=17227, stockCode=21948, purch=1),
#  Row(custId=15304, stockCode=22699, purch=1),
#  Row(custId=15301, stockCode=22810, purch=1),
#  Row(custId=14708, stockCode=22551, purch=1),
#  Row(custId=16898, stockCode=22121, purch=1),
#  Row(custId=16550, stockCode=22197, purch=1),
#  Row(custId=13089, stockCode=22654, purch=1),
#  Row(custId=15356, stockCode=20975, purch=1),
#  Row(custId=15356, stockCode=21175, purch=1),
#  Row(custId=17920, stockCode=84707, purch=1),
#  Row(custId=13564, stockCode=21479, purch=1),
#  Row(custId=14907, stockCode=48188, purch=1),
#  Row(custId=17017, stockCode=21918, purch=1),
#  Row(custId=15024, stockCode=22459, purch=1),
#  Row(custId=16904, stockCode=85099, purch=1),
#  Row(custId=17419, stockCode=22444, purch=1),
#  Row(custId=14796, stockCode=22295, purch=1),
#  Row(custId=16558, stockCode=22301, purch=1),
#  Row(custId=15021, stockCode=22570, purch=1),
#  Row(custId=16713, stockCode=22766, purch=1),
#  Row(custId=17262, stockCode=71053, purch=1),
#  Row(custId=15680, stockCode=22587, purch=1),
#  Row(custId=13077, stockCode=21498, purch=1),
#  Row(custId=15358, stockCode=22501, purch=1),
#  Row(custId=13854, stockCode=20749, purch=1),
#  Row(custId=14911, stockCode=22840, purch=1),
#  Row(custId=14527, stockCode=85048, purch=1),
#  Row(custId=16520, stockCode=21107, purch=1),
#  Row(custId=16520, stockCode=22107, purch=1),
#  Row(custId=14667, stockCode=21868, purch=1),
#  Row(custId=17097, stockCode=35958, purch=1),
#  Row(custId=13327, stockCode=85048, purch=1),
#  Row(custId=15555, stockCode=22212, purch=1),
#  Row(custId=15555, stockCode=21812, purch=1),
#  Row(custId=15805, stockCode=21562, purch=1),
#  Row(custId=15723, stockCode=22396, purch=1),
#  Row(custId=14256, stockCode=20675, purch=1),
#  Row(custId=12748, stockCode=21871, purch=1),
#  Row(custId=15514, stockCode=22729, purch=1),
#  Row(custId=15503, stockCode=84536, purch=1),
#  Row(custId=16923, stockCode=22796, purch=1),
#  Row(custId=14159, stockCode=22664, purch=1),
#  Row(custId=17218, stockCode=21481, purch=1),
#  Row(custId=17917, stockCode=16218, purch=1),
#  Row(custId=15998, stockCode=22621, purch=1),
#  Row(custId=13198, stockCode=21221, purch=1),
#  Row(custId=15311, stockCode=21240, purch=1),
#  Row(custId=15808, stockCode=22451, purch=1),
#  Row(custId=16455, stockCode=22112, purch=1),
#  Row(custId=14298, stockCode=79321, purch=1),
#  Row(custId=14415, stockCode=84792, purch=1),
#  Row(custId=16556, stockCode=20975, purch=1),
#  Row(custId=13097, stockCode=84358, purch=1),
#  Row(custId=17912, stockCode=22203, purch=1),
#  Row(custId=16145, stockCode=22782, purch=1),
#  Row(custId=13495, stockCode=84832, purch=1),
#  Row(custId=15950, stockCode=84997, purch=1),
#  Row(custId=17551, stockCode=22960, purch=1),
#  Row(custId=17189, stockCode=21154, purch=1),
#  Row(custId=13093, stockCode=22706, purch=1),
#  Row(custId=12748, stockCode=47471, purch=1),
#  Row(custId=15194, stockCode=85169, purch=1),
#  Row(custId=15620, stockCode=18007, purch=1),
#  Row(custId=18176, stockCode=22435, purch=1),
#  Row(custId=18260, stockCode=21527, purch=1),
#  Row(custId=17392, stockCode=22443, purch=1),
#  Row(custId=12471, stockCode=22720, purch=1),
#  Row(custId=14146, stockCode=22745, purch=1),
#  Row(custId=14146, stockCode=84945, purch=1),
#  Row(custId=12668, stockCode=21231, purch=1),
#  Row(custId=14646, stockCode=22445, purch=1),
#  Row(custId=16143, stockCode=22656, purch=1),
#  Row(custId=12681, stockCode=20750, purch=1),
#  Row(custId=15867, stockCode=21668, purch=1),
#  Row(custId=17340, stockCode=82567, purch=1),
#  Row(custId=14085, stockCode=20802, purch=1),
#  Row(custId=13304, stockCode=85099, purch=1),
#  Row(custId=17841, stockCode=22630, purch=1),
#  Row(custId=15164, stockCode=84879, purch=1),
#  Row(custId=16725, stockCode=22722, purch=1),
#  Row(custId=16241, stockCode=21430, purch=1),
#  Row(custId=16112, stockCode=21403, purch=1),
#  Row(custId=17511, stockCode=21240, purch=1),
#  Row(custId=13199, stockCode=22584, purch=1),
#  Row(custId=17585, stockCode=22702, purch=1),
#  Row(custId=15298, stockCode=79321, purch=1),
#  Row(custId=15271, stockCode=22720, purch=1),
#  Row(custId=13458, stockCode=20801, purch=1),
#  Row(custId=15194, stockCode=22969, purch=1),
#  Row(custId=16473, stockCode=20846, purch=1),
#  Row(custId=12489, stockCode=21054, purch=1),
#  Row(custId=13593, stockCode=84406, purch=1),
#  Row(custId=17796, stockCode=22495, purch=1),
#  Row(custId=14800, stockCode=22747, purch=1),
#  Row(custId=16833, stockCode=22326, purch=1),
#  Row(custId=17800, stockCode=22147, purch=1),
#  Row(custId=16549, stockCode=21034, purch=1),
#  Row(custId=14702, stockCode=21973, purch=1),
#  Row(custId=17757, stockCode=22138, purch=1),
#  Row(custId=15326, stockCode=21485, purch=1),
#  Row(custId=14229, stockCode=22674, purch=1),
#  Row(custId=16351, stockCode=22960, purch=1),
#  Row(custId=14669, stockCode=22194, purch=1),
#  Row(custId=13267, stockCode=21668, purch=1),
#  Row(custId=13113, stockCode=47566, purch=1),
#  Row(custId=14040, stockCode=22667, purch=1),
#  Row(custId=13284, stockCode=21039, purch=1),
#  Row(custId=15835, stockCode=22652, purch=1),
#  Row(custId=16161, stockCode=21390, purch=1),
#  Row(custId=15694, stockCode=22469, purch=1),
#  Row(custId=16503, stockCode=85136, purch=1),
#  Row(custId=17744, stockCode=85019, purch=1),
#  Row(custId=16775, stockCode=22072, purch=1),
#  Row(custId=12578, stockCode=21561, purch=1),
#  Row(custId=17581, stockCode=84050, purch=1),
#  Row(custId=15570, stockCode=22457, purch=1),
#  Row(custId=14329, stockCode=22974, purch=1),
#  Row(custId=15535, stockCode=85152, purch=1),
#  Row(custId=14657, stockCode=85038, purch=1),
#  Row(custId=14657, stockCode=22838, purch=1),
#  Row(custId=16033, stockCode=22926, purch=1),
#  Row(custId=12356, stockCode=84375, purch=1),
#  Row(custId=17491, stockCode=84380, purch=1),
#  Row(custId=16422, stockCode=22333, purch=1),
#  Row(custId=17722, stockCode=21633, purch=1),
#  Row(custId=15606, stockCode=22725, purch=1),
#  Row(custId=14646, stockCode=22245, purch=1),
#  Row(custId=14307, stockCode=21188, purch=1),
#  Row(custId=17611, stockCode=21340, purch=1),
#  Row(custId=14031, stockCode=46000, purch=1),
#  Row(custId=17231, stockCode=82600, purch=1),
#  Row(custId=17231, stockCode=46000, purch=1),
#  Row(custId=15529, stockCode=22374, purch=1),
#  Row(custId=15498, stockCode=22721, purch=1),
#  Row(custId=15174, stockCode=84509, purch=1),
#  Row(custId=17504, stockCode=22499, purch=1),
#  Row(custId=17504, stockCode=22699, purch=1),
#  Row(custId=13999, stockCode=48184, purch=1),
#  Row(custId=14692, stockCode=22743, purch=1),
#  Row(custId=14224, stockCode=21459, purch=1),
#  Row(custId=17858, stockCode=40001, purch=1),
#  Row(custId=16983, stockCode=22776, purch=1),
#  Row(custId=16558, stockCode=22501, purch=1),
#  Row(custId=14130, stockCode=21537, purch=1),
#  Row(custId=13615, stockCode=84992, purch=1),
#  Row(custId=14409, stockCode=85014, purch=1),
#  Row(custId=15967, stockCode=22168, purch=1),
#  Row(custId=16222, stockCode=21333, purch=1),
#  Row(custId=16222, stockCode=21733, purch=1),
#  Row(custId=14189, stockCode=21754, purch=1),
#  Row(custId=16943, stockCode=22456, purch=1),
#  Row(custId=12609, stockCode=22614, purch=1),
#  Row(custId=16133, stockCode=84826, purch=1),
#  Row(custId=13534, stockCode=22189, purch=1),
#  Row(custId=13534, stockCode=22789, purch=1),
#  Row(custId=14978, stockCode=22961, purch=1),
#  Row(custId=13113, stockCode=22766, purch=1),
#  Row(custId=13113, stockCode=21166, purch=1),
#  Row(custId=16714, stockCode=22329, purch=1),
#  Row(custId=13754, stockCode=22449, purch=1),
#  Row(custId=12997, stockCode=21658, purch=1),
#  Row(custId=17540, stockCode=22967, purch=1),
#  Row(custId=12868, stockCode=21231, purch=1),
#  Row(custId=18125, stockCode=22722, purch=1),
#  Row(custId=15547, stockCode=22508, purch=1),
#  Row(custId=16326, stockCode=20685, purch=1),
#  Row(custId=16770, stockCode=22457, purch=1),
#  Row(custId=15415, stockCode=84992, purch=1),
#  Row(custId=14426, stockCode=85185, purch=1),
#  Row(custId=15448, stockCode=22971, purch=1),
#  Row(custId=12476, stockCode=21135, purch=1),
#  Row(custId=18145, stockCode=20982, purch=1),
#  Row(custId=18145, stockCode=22382, purch=1),
#  Row(custId=14006, stockCode=20725, purch=1),
#  Row(custId=14911, stockCode=85040, purch=1),
#  Row(custId=13881, stockCode=22150, purch=1),
#  Row(custId=13093, stockCode=21506, purch=1),
#  Row(custId=15226, stockCode=21985, purch=1),
#  Row(custId=16378, stockCode=22961, purch=1),
#  Row(custId=18041, stockCode=21830, purch=1),
#  Row(custId=14044, stockCode=20719, purch=1),
#  Row(custId=13871, stockCode=22720, purch=1),
#  Row(custId=14778, stockCode=22961, purch=1),
#  Row(custId=14778, stockCode=22561, purch=1),
#  Row(custId=14534, stockCode=22989, purch=1),
#  Row(custId=13334, stockCode=22189, purch=1),
#  Row(custId=16686, stockCode=22565, purch=1),
#  Row(custId=14048, stockCode=22371, purch=1),
#  Row(custId=17841, stockCode=23230, purch=1),
#  Row(custId=16265, stockCode=21742, purch=1),
#  Row(custId=16553, stockCode=22486, purch=1),
#  Row(custId=17083, stockCode=20676, purch=1),
#  Row(custId=12462, stockCode=71053, purch=1),
#  Row(custId=17843, stockCode=84356, purch=1),
#  Row(custId=14081, stockCode=22550, purch=1),
#  Row(custId=17677, stockCode=21498, purch=1),
#  Row(custId=17085, stockCode=10002, purch=1),
#  Row(custId=17472, stockCode=22083, purch=1),
#  Row(custId=12415, stockCode=21192, purch=1),
#  Row(custId=17348, stockCode=35471, purch=1),
#  Row(custId=14961, stockCode=21390, purch=1),
#  Row(custId=16431, stockCode=79000, purch=1),
#  Row(custId=12616, stockCode=22555, purch=1),
#  Row(custId=15370, stockCode=84857, purch=1),
#  Row(custId=14156, stockCode=84375, purch=1),
#  Row(custId=15059, stockCode=21164, purch=1),
#  Row(custId=12431, stockCode=21000, purch=1),
#  Row(custId=13178, stockCode=16161, purch=1),
#  Row(custId=13425, stockCode=22222, purch=1),
#  Row(custId=13425, stockCode=22822, purch=1),
#  Row(custId=12852, stockCode=22423, purch=1),
#  Row(custId=15755, stockCode=21212, purch=1),
#  Row(custId=13799, stockCode=22384, purch=1),
#  Row(custId=13744, stockCode=16219, purch=1),
#  Row(custId=13744, stockCode=22419, purch=1),
#  Row(custId=17050, stockCode=22897, purch=1),
#  Row(custId=12988, stockCode=90191, purch=1),
#  Row(custId=17323, stockCode=84596, purch=1),
#  Row(custId=14646, stockCode=21245, purch=1),
#  Row(custId=15146, stockCode=22745, purch=1),
#  Row(custId=13044, stockCode=22919, purch=1),
#  Row(custId=17994, stockCode=84569, purch=1),
#  Row(custId=14895, stockCode=22832, purch=1),
#  Row(custId=12845, stockCode=20682, purch=1),
#  Row(custId=16940, stockCode=22367, purch=1),
#  Row(custId=16940, stockCode=47567, purch=1),
#  Row(custId=18172, stockCode=22583, purch=1),
#  Row(custId=17171, stockCode=22420, purch=1),
#  Row(custId=18231, stockCode=72800, purch=1),
#  Row(custId=17377, stockCode=22998, purch=1),
#  Row(custId=12633, stockCode=22326, purch=1),
#  Row(custId=13345, stockCode=22382, purch=1),
#  Row(custId=12841, stockCode=22230, purch=1),
#  Row(custId=13684, stockCode=85039, purch=1),
#  Row(custId=16598, stockCode=22021, purch=1),
#  Row(custId=15951, stockCode=22760, purch=1),
#  Row(custId=17516, stockCode=22055, purch=1),
#  Row(custId=14472, stockCode=22283, purch=1),
#  Row(custId=15547, stockCode=21508, purch=1),
#  Row(custId=17894, stockCode=22469, purch=1),
#  Row(custId=12781, stockCode=22250, purch=1),
#  Row(custId=16057, stockCode=22838, purch=1),
#  Row(custId=14740, stockCode=22967, purch=1),
#  Row(custId=14740, stockCode=20967, purch=1),
#  Row(custId=15676, stockCode=10135, purch=1),
#  Row(custId=15416, stockCode=84755, purch=1),
#  Row(custId=15416, stockCode=21955, purch=1),
#  Row(custId=14180, stockCode=22487, purch=1),
#  Row(custId=17048, stockCode=20971, purch=1),
#  Row(custId=15643, stockCode=16156, purch=1),
#  Row(custId=17426, stockCode=48185, purch=1),
#  Row(custId=13230, stockCode=22637, purch=1),
#  Row(custId=16709, stockCode=20914, purch=1),
#  Row(custId=14524, stockCode=22759, purch=1),
#  Row(custId=17416, stockCode=22355, purch=1),
#  Row(custId=12417, stockCode=21318, purch=1),
#  Row(custId=15220, stockCode=18007, purch=1),
#  Row(custId=14499, stockCode=82484, purch=1),
#  Row(custId=14504, stockCode=21899, purch=1),
#  Row(custId=16621, stockCode=84970, purch=1),
#  Row(custId=16316, stockCode=22655, purch=1),
#  Row(custId=16356, stockCode=21175, purch=1),
#  Row(custId=14817, stockCode=20718, purch=1),
#  Row(custId=15498, stockCode=79321, purch=1),
#  Row(custId=17817, stockCode=20718, purch=1),
#  Row(custId=15806, stockCode=22525, purch=1),
#  Row(custId=15819, stockCode=15044, purch=1),
#  Row(custId=16710, stockCode=22077, purch=1),
#  Row(custId=14367, stockCode=20768, purch=1),
#  Row(custId=14426, stockCode=48185, purch=1),
#  Row(custId=17049, stockCode=22134, purch=1),
#  Row(custId=15502, stockCode=22973, purch=1),
#  Row(custId=15529, stockCode=20974, purch=1),
#  Row(custId=15529, stockCode=22174, purch=1),
#  Row(custId=14603, stockCode=15036, purch=1),
#  Row(custId=14156, stockCode=21975, purch=1),
#  Row(custId=12370, stockCode=22857, purch=1),
#  Row(custId=16475, stockCode=21172, purch=1),
#  Row(custId=15513, stockCode=47566, purch=1),
#  Row(custId=18149, stockCode=21034, purch=1),
#  Row(custId=16652, stockCode=22423, purch=1),
#  Row(custId=13226, stockCode=21985, purch=1),
#  Row(custId=14352, stockCode=85123, purch=1),
#  Row(custId=16768, stockCode=21531, purch=1),
#  Row(custId=15547, stockCode=21908, purch=1),
#  Row(custId=14502, stockCode=21773, purch=1),
#  Row(custId=13708, stockCode=82551, purch=1),
#  Row(custId=15125, stockCode=22722, purch=1),
#  Row(custId=13263, stockCode=22616, purch=1),
#  Row(custId=13082, stockCode=21913, purch=1),
#  Row(custId=17542, stockCode=22493, purch=1),
#  Row(custId=14534, stockCode=84789, purch=1),
#  Row(custId=13451, stockCode=22060, purch=1),
#  Row(custId=12868, stockCode=85231, purch=1),
#  Row(custId=15687, stockCode=21928, purch=1),
#  Row(custId=13668, stockCode=22431, purch=1),
#  Row(custId=17504, stockCode=21899, purch=1),
#  Row(custId=14505, stockCode=22662, purch=1),
#  Row(custId=13185, stockCode=22502, purch=1),
#  Row(custId=13650, stockCode=22697, purch=1),
#  Row(custId=15433, stockCode=20726, purch=1),
#  Row(custId=15695, stockCode=84032, purch=1),
#  Row(custId=12948, stockCode=22271, purch=1),
#  Row(custId=17134, stockCode=22189, purch=1),
#  Row(custId=17795, stockCode=22332, purch=1),
#  Row(custId=14232, stockCode=21163, purch=1),
#  Row(custId=14769, stockCode=22694, purch=1),
#  Row(custId=14769, stockCode=22294, purch=1),
#  Row(custId=14769, stockCode=22894, purch=1),
#  Row(custId=13592, stockCode=21843, purch=1),
#  Row(custId=15669, stockCode=23194, purch=1),
#  Row(custId=13021, stockCode=20970, purch=1),
#  Row(custId=15996, stockCode=22295, purch=1),
#  Row(custId=13491, stockCode=82580, purch=1),
#  Row(custId=16791, stockCode=21080, purch=1),
#  Row(custId=12867, stockCode=22068, purch=1),
#  Row(custId=17231, stockCode=84800, purch=1),
#  Row(custId=13869, stockCode=48194, purch=1),
#  Row(custId=15998, stockCode=47421, purch=1),
#  Row(custId=16135, stockCode=85152, purch=1),
#  Row(custId=17705, stockCode=22662, purch=1),
#  Row(custId=17019, stockCode=21244, purch=1),
#  Row(custId=17507, stockCode=85188, purch=1),
#  Row(custId=17096, stockCode=22595, purch=1),
#  Row(custId=15021, stockCode=22170, purch=1),
#  Row(custId=17644, stockCode=20719, purch=1),
#  Row(custId=13069, stockCode=22994, purch=1),
#  Row(custId=13069, stockCode=21394, purch=1),
#  Row(custId=17754, stockCode=85049, purch=1),
#  Row(custId=17450, stockCode=21897, purch=1),
#  Row(custId=12553, stockCode=21086, purch=1),
#  Row(custId=13097, stockCode=22558, purch=1),
#  Row(custId=12545, stockCode=21382, purch=1),
#  Row(custId=14758, stockCode=22301, purch=1),
#  Row(custId=16923, stockCode=22996, purch=1),
#  Row(custId=14472, stockCode=82483, purch=1),
#  Row(custId=13357, stockCode=22938, purch=1),
#  Row(custId=14410, stockCode=22977, purch=1),
#  Row(custId=14410, stockCode=23177, purch=1),
#  Row(custId=15033, stockCode=22926, purch=1),
#  Row(custId=15644, stockCode=22719, purch=1),
#  Row(custId=17428, stockCode=20711, purch=1),
#  Row(custId=13769, stockCode=82494, purch=1),
#  Row(custId=16871, stockCode=22720, purch=1),
#  Row(custId=15696, stockCode=22595, purch=1),
#  Row(custId=17931, stockCode=22900, purch=1),
#  Row(custId=15906, stockCode=22425, purch=1),
#  Row(custId=14189, stockCode=22754, purch=1),
#  Row(custId=16657, stockCode=16238, purch=1),
#  Row(custId=16788, stockCode=84991, purch=1),
#  Row(custId=14527, stockCode=22248, purch=1),
#  Row(custId=17861, stockCode=22090, purch=1),
#  Row(custId=17735, stockCode=20752, purch=1),
#  Row(custId=18161, stockCode=21790, purch=1),
#  Row(custId=16609, stockCode=22614, purch=1),
#  Row(custId=15356, stockCode=84375, purch=1),
#  Row(custId=15356, stockCode=21975, purch=1),
#  Row(custId=17337, stockCode=21078, purch=1),
#  Row(custId=15039, stockCode=47504, purch=1),
#  Row(custId=13294, stockCode=21469, purch=1),
#  Row(custId=14535, stockCode=20752, purch=1),
#  Row(custId=15145, stockCode=21982, purch=1),
#  Row(custId=15145, stockCode=20982, purch=1),
#  Row(custId=17409, stockCode=85014, purch=1),
#  Row(custId=16241, stockCode=22030, purch=1),
#  Row(custId=15235, stockCode=22652, purch=1),
#  Row(custId=14446, stockCode=21245, purch=1),
#  Row(custId=16623, stockCode=22296, purch=1),
#  Row(custId=14243, stockCode=21756, purch=1),
#  Row(custId=17035, stockCode=23052, purch=1),
#  Row(custId=13548, stockCode=22071, purch=1),
#  Row(custId=17372, stockCode=23183, purch=1),
#  Row(custId=13610, stockCode=21977, purch=1),
#  Row(custId=13632, stockCode=21163, purch=1),
#  Row(custId=13113, stockCode=22966, purch=1),
#  Row(custId=12701, stockCode=23010, purch=1),
#  Row(custId=12363, stockCode=48116, purch=1),
#  Row(custId=13700, stockCode=22047, purch=1),
#  Row(custId=14669, stockCode=85194, purch=1),
#  Row(custId=12854, stockCode=22149, purch=1),
#  Row(custId=17017, stockCode=21718, purch=1),
#  Row(custId=13208, stockCode=72051, purch=1),
#  Row(custId=13221, stockCode=21770, purch=1),
#  Row(custId=15813, stockCode=22666, purch=1),
#  Row(custId=17704, stockCode=22499, purch=1),
#  Row(custId=15416, stockCode=21755, purch=1),
#  Row(custId=14390, stockCode=20717, purch=1),
#  Row(custId=16520, stockCode=21907, purch=1),
#  Row(custId=16393, stockCode=23206, purch=1),
#  Row(custId=17930, stockCode=21137, purch=1),
#  Row(custId=13952, stockCode=21523, purch=1),
#  Row(custId=12769, stockCode=22494, purch=1),
#  Row(custId=15985, stockCode=22702, purch=1),
#  Row(custId=14524, stockCode=22359, purch=1),
#  Row(custId=14524, stockCode=21559, purch=1),
#  Row(custId=15745, stockCode=23182, purch=1),
#  Row(custId=16033, stockCode=21326, purch=1),
#  Row(custId=16550, stockCode=84997, purch=1),
#  Row(custId=18009, stockCode=16014, purch=1),
#  Row(custId=15508, stockCode=22151, purch=1),
#  Row(custId=12947, stockCode=21508, purch=1),
#  Row(custId=14152, stockCode=20723, purch=1),
#  Row(custId=14626, stockCode=21985, purch=1),
#  Row(custId=14626, stockCode=21385, purch=1),
#  Row(custId=15805, stockCode=22562, purch=1),
#  Row(custId=15517, stockCode=62018, purch=1),
#  Row(custId=16133, stockCode=22626, purch=1),
#  Row(custId=16185, stockCode=22502, purch=1),
#  Row(custId=17631, stockCode=46000, purch=1),
#  Row(custId=16019, stockCode=15044, purch=1),
#  Row(custId=12708, stockCode=22551, purch=1),
#  Row(custId=14961, stockCode=22990, purch=1),
#  Row(custId=13209, stockCode=22614, purch=1),
#  Row(custId=17613, stockCode=22666, purch=1),
#  Row(custId=16823, stockCode=21096, purch=1),
#  Row(custId=14606, stockCode=20725, purch=1),
#  Row(custId=12621, stockCode=22570, purch=1),
#  Row(custId=13637, stockCode=84978, purch=1),
#  Row(custId=13637, stockCode=82578, purch=1),
#  Row(custId=16755, stockCode=84212, purch=1),
#  Row(custId=14740, stockCode=20767, purch=1),
#  Row(custId=17874, stockCode=23009, purch=1),
#  Row(custId=15622, stockCode=21533, purch=1),
#  Row(custId=17893, stockCode=22706, purch=1),
#  Row(custId=16904, stockCode=22499, purch=1),
#  Row(custId=18037, stockCode=20978, purch=1),
#  Row(custId=12524, stockCode=21559, purch=1),
#  Row(custId=12683, stockCode=23076, purch=1),
#  Row(custId=18062, stockCode=23053, purch=1),
#  Row(custId=15620, stockCode=22607, purch=1),
#  Row(custId=14135, stockCode=22752, purch=1),
#  Row(custId=13263, stockCode=21216, purch=1),
#  Row(custId=14245, stockCode=84882, purch=1),
#  Row(custId=12720, stockCode=22907, purch=1),
#  Row(custId=13012, stockCode=21703, purch=1),
#  Row(custId=12886, stockCode=22965, purch=1),
#  Row(custId=13268, stockCode=21231, purch=1),
#  Row(custId=13220, stockCode=22607, purch=1),
#  Row(custId=17646, stockCode=22845, purch=1),
#  Row(custId=13883, stockCode=22676, purch=1),
#  Row(custId=18239, stockCode=22904, purch=1),
#  Row(custId=15356, stockCode=22975, purch=1),
#  Row(custId=13269, stockCode=21394, purch=1),
#  Row(custId=13081, stockCode=21750, purch=1),
#  Row(custId=17504, stockCode=23299, purch=1),
#  Row(custId=15796, stockCode=35095, purch=1),
#  Row(custId=14911, stockCode=22440, purch=1),
#  Row(custId=14684, stockCode=22639, purch=1),
#  Row(custId=14684, stockCode=22439, purch=1),
#  Row(custId=12748, stockCode=79071, purch=1),
#  Row(custId=13004, stockCode=22999, purch=1),
#  Row(custId=18120, stockCode=22507, purch=1),
#  Row(custId=16477, stockCode=23298, purch=1),
#  Row(custId=13178, stockCode=21561, purch=1),
#  Row(custId=16431, stockCode=21000, purch=1),
#  Row(custId=16431, stockCode=23200, purch=1),
#  Row(custId=15756, stockCode=21175, purch=1),
#  Row(custId=15756, stockCode=22375, purch=1),
#  Row(custId=16320, stockCode=22707, purch=1),
#  Row(custId=16320, stockCode=21907, purch=1),
#  Row(custId=14462, stockCode=85053, purch=1),
#  Row(custId=13098, stockCode=79321, purch=1),
#  Row(custId=14920, stockCode=21907, purch=1),
#  Row(custId=17428, stockCode=22711, purch=1),
#  Row(custId=14573, stockCode=22746, purch=1),
#  Row(custId=17677, stockCode=23298, purch=1),
#  Row(custId=15079, stockCode=22824, purch=1),
#  Row(custId=16644, stockCode=22919, purch=1),
#  Row(custId=16712, stockCode=23203, purch=1),
#  Row(custId=17764, stockCode=21279, purch=1),
#  Row(custId=17764, stockCode=22079, purch=1),
#  Row(custId=14651, stockCode=22460, purch=1),
#  Row(custId=17315, stockCode=22092, purch=1),
#  Row(custId=17337, stockCode=23078, purch=1),
#  Row(custId=15845, stockCode=82482, purch=1),
#  Row(custId=15529, stockCode=20774, purch=1),
#  Row(custId=17139, stockCode=23204, purch=1),
#  Row(custId=13623, stockCode=21896, purch=1),
#  Row(custId=15164, stockCode=22479, purch=1),
#  Row(custId=17758, stockCode=23301, purch=1),
#  Row(custId=13319, stockCode=23144, purch=1),
#  Row(custId=16912, stockCode=23203, purch=1),
#  Row(custId=17054, stockCode=21749, purch=1),
#  Row(custId=14755, stockCode=21212, purch=1),
#  Row(custId=18102, stockCode=48173, purch=1),
#  Row(custId=16899, stockCode=82484, purch=1),
#  Row(custId=16899, stockCode=23284, purch=1),
#  Row(custId=17220, stockCode=23207, purch=1),
#  Row(custId=12415, stockCode=22992, purch=1),
#  Row(custId=16818, stockCode=22081, purch=1),
#  Row(custId=14895, stockCode=21232, purch=1),
#  Row(custId=17245, stockCode=82482, purch=1),
#  Row(custId=17245, stockCode=23082, purch=1),
#  Row(custId=16813, stockCode=22066, purch=1),
#  Row(custId=16813, stockCode=22666, purch=1),
#  Row(custId=13418, stockCode=23281, purch=1),
#  Row(custId=15862, stockCode=23053, purch=1),
#  Row(custId=15791, stockCode=21080, purch=1),
#  Row(custId=13658, stockCode=23201, purch=1),
#  Row(custId=15370, stockCode=22057, purch=1),
#  Row(custId=15856, stockCode=20675, purch=1),
#  Row(custId=14112, stockCode=23203, purch=1),
#  Row(custId=15601, stockCode=23110, purch=1),
#  Row(custId=13243, stockCode=22156, purch=1),
#  Row(custId=13555, stockCode=22212, purch=1),
#  Row(custId=16931, stockCode=23300, purch=1),
#  Row(custId=15716, stockCode=22855, purch=1),
#  Row(custId=14769, stockCode=21094, purch=1),
#  Row(custId=13758, stockCode=23301, purch=1),
#  Row(custId=15288, stockCode=22691, purch=1),
#  Row(custId=13078, stockCode=22461, purch=1),
#  Row(custId=14903, stockCode=21136, purch=1),
#  Row(custId=18160, stockCode=22627, purch=1),
#  Row(custId=14191, stockCode=21080, purch=1),
#  Row(custId=15882, stockCode=21713, purch=1),
#  Row(custId=15852, stockCode=22423, purch=1),
#  Row(custId=13488, stockCode=23091, purch=1),
#  Row(custId=14194, stockCode=22969, purch=1),
#  Row(custId=18242, stockCode=22993, purch=1),
#  Row(custId=16889, stockCode=23254, purch=1),
#  Row(custId=15897, stockCode=22558, purch=1),
#  Row(custId=16558, stockCode=23101, purch=1),
#  Row(custId=16470, stockCode=22557, purch=1),
#  Row(custId=18231, stockCode=82600, purch=1),
#  Row(custId=15163, stockCode=21116, purch=1),
#  Row(custId=14842, stockCode=22993, purch=1),
#  Row(custId=14842, stockCode=22193, purch=1),
#  Row(custId=16969, stockCode=21094, purch=1),
#  Row(custId=17191, stockCode=23280, purch=1),
#  Row(custId=16424, stockCode=71459, purch=1),
#  Row(custId=13334, stockCode=22989, purch=1),
#  Row(custId=13334, stockCode=22789, purch=1),
#  Row(custId=12971, stockCode=22420, purch=1),
#  Row(custId=14088, stockCode=23091, purch=1),
#  Row(custId=13248, stockCode=23171, purch=1),
#  Row(custId=14891, stockCode=22380, purch=1),
#  Row(custId=14891, stockCode=21980, purch=1),
#  Row(custId=12468, stockCode=22431, purch=1),
#  Row(custId=17589, stockCode=22554, purch=1),
#  Row(custId=15152, stockCode=21123, purch=1),
#  Row(custId=15349, stockCode=22434, purch=1),
#  Row(custId=12417, stockCode=23118, purch=1),
#  Row(custId=13865, stockCode=21742, purch=1),
#  Row(custId=14312, stockCode=23203, purch=1),
#  Row(custId=15150, stockCode=22597, purch=1),
#  Row(custId=15150, stockCode=22797, purch=1),
#  Row(custId=14156, stockCode=21175, purch=1),
#  Row(custId=17252, stockCode=21623, purch=1),
#  Row(custId=17252, stockCode=22223, purch=1),
#  Row(custId=14606, stockCode=22325, purch=1),
#  Row(custId=13643, stockCode=22356, purch=1),
#  Row(custId=14583, stockCode=84576, purch=1),
#  Row(custId=14711, stockCode=23240, purch=1),
#  Row(custId=17015, stockCode=21992, purch=1),
#  Row(custId=13050, stockCode=22297, purch=1),
#  Row(custId=14375, stockCode=21272, purch=1),
#  Row(custId=14745, stockCode=22382, purch=1),
#  Row(custId=17828, stockCode=22511, purch=1),
#  Row(custId=14911, stockCode=20840, purch=1),
#  Row(custId=13001, stockCode=84510, purch=1),
#  Row(custId=13115, stockCode=22492, purch=1),
#  Row(custId=13466, stockCode=22305, purch=1),
#  Row(custId=14056, stockCode=23275, purch=1),
#  Row(custId=17360, stockCode=22627, purch=1),
#  Row(custId=13741, stockCode=21530, purch=1),
#  Row(custId=13510, stockCode=21877, purch=1),
#  Row(custId=12406, stockCode=22725, purch=1),
#  Row(custId=14231, stockCode=82600, purch=1),
#  Row(custId=17169, stockCode=82494, purch=1),
#  Row(custId=14911, stockCode=23240, purch=1),
#  Row(custId=12597, stockCode=15058, purch=1),
#  Row(custId=14178, stockCode=22161, purch=1),
#  Row(custId=16938, stockCode=23241, purch=1),
#  Row(custId=17422, stockCode=10133, purch=1),
#  Row(custId=13761, stockCode=21790, purch=1),
#  Row(custId=12714, stockCode=21929, purch=1),
#  Row(custId=17795, stockCode=85132, purch=1),
#  Row(custId=17027, stockCode=23148, purch=1),
#  Row(custId=14461, stockCode=21890, purch=1),
#  Row(custId=15656, stockCode=23275, purch=1),
#  Row(custId=17155, stockCode=21212, purch=1),
#  Row(custId=17511, stockCode=23240, purch=1),
#  Row(custId=16904, stockCode=21899, purch=1),
#  Row(custId=16898, stockCode=79321, purch=1),
#  Row(custId=12415, stockCode=21992, purch=1),
#  Row(custId=12415, stockCode=23192, purch=1),
#  Row(custId=16814, stockCode=23029, purch=1),
#  Row(custId=16843, stockCode=22956, purch=1),
#  Row(custId=17426, stockCode=22985, purch=1),
#  Row(custId=14936, stockCode=21115, purch=1),
#  Row(custId=12951, stockCode=22960, purch=1),
#  Row(custId=13632, stockCode=84563, purch=1),
#  Row(custId=15700, stockCode=22847, purch=1),
#  Row(custId=15535, stockCode=82552, purch=1),
#  Row(custId=15076, stockCode=21535, purch=1),
#  Row(custId=14646, stockCode=23245, purch=1),
#  Row(custId=15921, stockCode=22670, purch=1),
#  Row(custId=15016, stockCode=84755, purch=1),
#  Row(custId=13815, stockCode=21992, purch=1),
#  Row(custId=16713, stockCode=21166, purch=1),
#  Row(custId=12432, stockCode=21563, purch=1),
#  Row(custId=17428, stockCode=23111, purch=1),
#  Row(custId=15280, stockCode=84987, purch=1),
#  Row(custId=15507, stockCode=23188, purch=1),
#  Row(custId=15507, stockCode=22188, purch=1),
#  Row(custId=14175, stockCode=22672, purch=1),
#  Row(custId=17420, stockCode=23207, purch=1),
#  Row(custId=12684, stockCode=15039, purch=1),
#  Row(custId=15059, stockCode=23164, purch=1),
#  Row(custId=15059, stockCode=22364, purch=1),
#  Row(custId=14156, stockCode=23175, purch=1),
#  Row(custId=14364, stockCode=22279, purch=1),
#  Row(custId=17651, stockCode=21260, purch=1),
#  Row(custId=12720, stockCode=22507, purch=1),
#  Row(custId=17370, stockCode=84857, purch=1),
#  Row(custId=16940, stockCode=22567, purch=1),
#  Row(custId=17799, stockCode=22384, purch=1),
#  Row(custId=17848, stockCode=23171, purch=1),
#  Row(custId=18283, stockCode=20676, purch=1),
#  Row(custId=15453, stockCode=22586, purch=1),
#  Row(custId=13408, stockCode=23251, purch=1),
#  Row(custId=14837, stockCode=22178, purch=1),
#  Row(custId=17323, stockCode=23196, purch=1),
#  Row(custId=14104, stockCode=85099, purch=1),
#  Row(custId=13614, stockCode=23229, purch=1),
#  Row(custId=17965, stockCode=23242, purch=1),
#  Row(custId=17750, stockCode=22997, purch=1),
#  Row(custId=14527, stockCode=22848, purch=1),
#  Row(custId=13988, stockCode=84991, purch=1),
#  Row(custId=13988, stockCode=47591, purch=1),
#  Row(custId=17706, stockCode=22625, purch=1),
#  Row(custId=17706, stockCode=22425, purch=1),
#  Row(custId=14282, stockCode=20713, purch=1),
#  Row(custId=13745, stockCode=21382, purch=1),
#  Row(custId=13745, stockCode=23182, purch=1),
#  Row(custId=17920, stockCode=21907, purch=1),
#  Row(custId=13285, stockCode=23202, purch=1),
#  Row(custId=13148, stockCode=22271, purch=1),
#  Row(custId=15952, stockCode=85123, purch=1),
#  Row(custId=16682, stockCode=21913, purch=1),
#  Row(custId=16861, stockCode=22090, purch=1),
#  Row(custId=15349, stockCode=85034, purch=1),
#  Row(custId=14034, stockCode=22689, purch=1),
#  Row(custId=13599, stockCode=22984, purch=1),
#  Row(custId=17861, stockCode=22890, purch=1),
#  Row(custId=18263, stockCode=20616, purch=1),
#  Row(custId=18263, stockCode=82616, purch=1),
#  Row(custId=13291, stockCode=84380, purch=1),
#  Row(custId=15267, stockCode=23268, purch=1),
#  Row(custId=12471, stockCode=23320, purch=1),
#  Row(custId=13699, stockCode=23284, purch=1),
#  Row(custId=15150, stockCode=20997, purch=1),
#  Row(custId=16012, stockCode=22303, purch=1),
#  Row(custId=17107, stockCode=48188, purch=1),
#  Row(custId=17031, stockCode=23200, purch=1),
#  Row(custId=15901, stockCode=23010, purch=1),
#  Row(custId=14534, stockCode=21989, purch=1),
#  Row(custId=16923, stockCode=84596, purch=1),
#  Row(custId=17126, stockCode=22085, purch=1),
#  Row(custId=13230, stockCode=22037, purch=1),
#  Row(custId=16014, stockCode=21429, purch=1),
#  Row(custId=14552, stockCode=85123, purch=1),
#  Row(custId=13675, stockCode=22772, purch=1),
#  Row(custId=15856, stockCode=22675, purch=1),
#  Row(custId=15577, stockCode=22998, purch=1),
#  Row(custId=16609, stockCode=85014, purch=1),
#  Row(custId=12720, stockCode=23307, purch=1),
#  Row(custId=15795, stockCode=85132, purch=1),
#  Row(custId=15752, stockCode=20723, purch=1),
#  Row(custId=12766, stockCode=23205, purch=1),
#  Row(custId=13012, stockCode=21903, purch=1),
#  Row(custId=14857, stockCode=22838, purch=1),
#  Row(custId=14907, stockCode=21588, purch=1),
#  Row(custId=18118, stockCode=22581, purch=1),
#  Row(custId=16931, stockCode=21900, purch=1),
#  Row(custId=13654, stockCode=22149, purch=1),
#  Row(custId=16744, stockCode=22419, purch=1),
#  Row(custId=17984, stockCode=22539, purch=1),
#  Row(custId=17984, stockCode=22139, purch=1),
#  Row(custId=12744, stockCode=21819, purch=1),
#  Row(custId=14808, stockCode=21251, purch=1),
#  Row(custId=13756, stockCode=21175, purch=1),
#  Row(custId=17779, stockCode=20724, purch=1),
#  Row(custId=17779, stockCode=21124, purch=1),
#  Row(custId=14178, stockCode=22361, purch=1),
#  Row(custId=15867, stockCode=23268, purch=1),
#  Row(custId=12560, stockCode=22627, purch=1),
#  Row(custId=16133, stockCode=22426, purch=1),
#  Row(custId=14704, stockCode=21899, purch=1),
#  Row(custId=17675, stockCode=20972, purch=1),
#  Row(custId=15260, stockCode=20727, purch=1),
#  Row(custId=17935, stockCode=22752, purch=1),
#  Row(custId=14298, stockCode=23321, purch=1),
#  Row(custId=14298, stockCode=23121, purch=1),
#  Row(custId=14085, stockCode=23002, purch=1),
#  Row(custId=14407, stockCode=23288, purch=1),
#  Row(custId=12626, stockCode=22385, purch=1),
#  Row(custId=15704, stockCode=85099, purch=1),
#  Row(custId=13029, stockCode=84874, purch=1),
#  Row(custId=16305, stockCode=22662, purch=1),
#  Row(custId=13956, stockCode=22575, purch=1),
#  Row(custId=16841, stockCode=23230, purch=1),
#  Row(custId=13814, stockCode=22629, purch=1),
#  Row(custId=14796, stockCode=23295, purch=1),
#  Row(custId=14232, stockCode=47563, purch=1),
#  Row(custId=17734, stockCode=21789, purch=1),
#  Row(custId=13588, stockCode=21791, purch=1),
#  Row(custId=15159, stockCode=22664, purch=1),
#  Row(custId=15513, stockCode=22766, purch=1),
#  Row(custId=16019, stockCode=23244, purch=1),
#  Row(custId=13730, stockCode=21137, purch=1),
#  Row(custId=15261, stockCode=21090, purch=1),
#  Row(custId=17975, stockCode=22872, purch=1),
#  Row(custId=14898, stockCode=23321, purch=1),
#  Row(custId=15639, stockCode=21504, purch=1),
#  Row(custId=14315, stockCode=21292, purch=1),
#  Row(custId=15120, stockCode=22707, purch=1),
#  Row(custId=16062, stockCode=23253, purch=1),
#  Row(custId=13316, stockCode=22055, purch=1),
#  Row(custId=16401, stockCode=23310, purch=1),
#  Row(custId=15532, stockCode=21063, purch=1),
#  Row(custId=14456, stockCode=23275, purch=1),
#  Row(custId=16655, stockCode=22712, purch=1),
#  Row(custId=12534, stockCode=22989, purch=1),
#  Row(custId=16332, stockCode=22063, purch=1),
#  Row(custId=16133, stockCode=23026, purch=1),
#  Row(custId=12347, stockCode=23308, purch=1),
#  Row(custId=12593, stockCode=23206, purch=1),
#  Row(custId=12644, stockCode=23319, purch=1),
#  Row(custId=12644, stockCode=23119, purch=1),
#  Row(custId=12378, stockCode=21561, purch=1),
#  Row(custId=12378, stockCode=16161, purch=1),
#  Row(custId=13437, stockCode=23178, purch=1),
#  Row(custId=17887, stockCode=21328, purch=1),
#  Row(custId=14088, stockCode=22491, purch=1),
#  Row(custId=16324, stockCode=21159, purch=1),
#  Row(custId=16348, stockCode=21471, purch=1),
#  Row(custId=12704, stockCode=85099, purch=1),
#  Row(custId=15249, stockCode=21934, purch=1),
#  Row(custId=15254, stockCode=23549, purch=1),
#  Row(custId=14535, stockCode=23152, purch=1),
#  Row(custId=16880, stockCode=48187, purch=1),
#  Row(custId=12610, stockCode=22377, purch=1),
#  Row(custId=15152, stockCode=21523, purch=1),
#  Row(custId=12865, stockCode=23142, purch=1),
#  Row(custId=15502, stockCode=23173, purch=1),
#  Row(custId=13016, stockCode=22955, purch=1),
#  Row(custId=16241, stockCode=22230, purch=1),
#  Row(custId=15632, stockCode=22163, purch=1),
#  Row(custId=17284, stockCode=22439, purch=1),
#  Row(custId=16746, stockCode=23345, purch=1),
#  Row(custId=16746, stockCode=22945, purch=1),
#  Row(custId=17293, stockCode=85106, purch=1),
#  Row(custId=16115, stockCode=21892, purch=1),
#  Row(custId=13940, stockCode=20767, purch=1),
#  Row(custId=12656, stockCode=37475, purch=1),
#  Row(custId=16961, stockCode=21790, purch=1),
#  Row(custId=13953, stockCode=21086, purch=1),
#  Row(custId=14057, stockCode=23238, purch=1),
#  Row(custId=17338, stockCode=23241, purch=1),
#  Row(custId=17338, stockCode=21041, purch=1),
#  Row(custId=12688, stockCode=23291, purch=1),
#  Row(custId=15189, stockCode=21754, purch=1),
#  Row(custId=17736, stockCode=22115, purch=1),
#  Row(custId=15867, stockCode=23068, purch=1),
#  Row(custId=15867, stockCode=22468, purch=1),
#  Row(custId=15159, stockCode=22464, purch=1),
#  Row(custId=12360, stockCode=22027, purch=1),
#  Row(custId=17725, stockCode=23322, purch=1),
#  Row(custId=18170, stockCode=22457, purch=1),
#  Row(custId=14246, stockCode=23245, purch=1),
#  Row(custId=13435, stockCode=23252, purch=1),
#  Row(custId=14529, stockCode=21374, purch=1),
#  Row(custId=15547, stockCode=23108, purch=1),
#  Row(custId=15801, stockCode=84510, purch=1),
#  Row(custId=16652, stockCode=22623, purch=1),
#  Row(custId=15443, stockCode=23356, purch=1),
#  Row(custId=17585, stockCode=22502, purch=1),
#  Row(custId=15033, stockCode=20726, purch=1),
#  Row(custId=17469, stockCode=48194, purch=1),
#  Row(custId=18147, stockCode=22508, purch=1),
#  Row(custId=13481, stockCode=23550, purch=1),
#  Row(custId=12567, stockCode=23168, purch=1),
#  Row(custId=15755, stockCode=23212, purch=1),
#  Row(custId=15249, stockCode=22734, purch=1),
#  Row(custId=14796, stockCode=21495, purch=1),
#  Row(custId=16723, stockCode=23196, purch=1),
#  Row(custId=16723, stockCode=22796, purch=1),
#  Row(custId=15932, stockCode=23263, purch=1),
#  Row(custId=13694, stockCode=22469, purch=1),
#  Row(custId=12748, stockCode=22271, purch=1),
#  Row(custId=12748, stockCode=85071, purch=1),
#  Row(custId=16340, stockCode=21967, purch=1),
#  Row(custId=14401, stockCode=23110, purch=1),
#  Row(custId=15764, stockCode=23079, purch=1),
#  Row(custId=13969, stockCode=22094, purch=1),
#  Row(custId=18200, stockCode=84947, purch=1),
#  Row(custId=18200, stockCode=23147, purch=1),
#  Row(custId=13527, stockCode=16048, purch=1),
#  Row(custId=16816, stockCode=23355, purch=1),
#  Row(custId=17346, stockCode=23345, purch=1),
#  Row(custId=14869, stockCode=21794, purch=1),
#  Row(custId=15866, stockCode=20705, purch=1),
#  Row(custId=13089, stockCode=23254, purch=1),
#  Row(custId=17299, stockCode=23084, purch=1),
#  Row(custId=12621, stockCode=23170, purch=1),
#  Row(custId=16278, stockCode=22061, purch=1),
#  Row(custId=12828, stockCode=22111, purch=1),
#  Row(custId=14276, stockCode=10135, purch=1),
#  Row(custId=16674, stockCode=22409, purch=1),
#  Row(custId=16326, stockCode=21485, purch=1),
#  Row(custId=16241, stockCode=84030, purch=1),
#  Row(custId=15364, stockCode=84879, purch=1),
#  Row(custId=16891, stockCode=22980, purch=1),
#  Row(custId=13881, stockCode=22950, purch=1),
#  Row(custId=16820, stockCode=22607, purch=1),
#  Row(custId=16918, stockCode=21181, purch=1),
#  Row(custId=13510, stockCode=84077, purch=1),
#  Row(custId=13210, stockCode=22577, purch=1),
#  Row(custId=17735, stockCode=22352, purch=1),
#  Row(custId=12683, stockCode=20676, purch=1),
#  Row(custId=18222, stockCode=22333, purch=1),
#  Row(custId=16426, stockCode=22385, purch=1),
#  Row(custId=13700, stockCode=84247, purch=1),
#  Row(custId=12787, stockCode=22028, purch=1),
#  Row(custId=16362, stockCode=23353, purch=1),
#  Row(custId=12635, stockCode=23052, purch=1),
#  Row(custId=13372, stockCode=21983, purch=1),
#  Row(custId=17864, stockCode=23379, purch=1),
#  Row(custId=16549, stockCode=23234, purch=1),
#  Row(custId=13450, stockCode=21497, purch=1),
#  Row(custId=16796, stockCode=23295, purch=1),
#  Row(custId=14432, stockCode=79163, purch=1),
#  Row(custId=15865, stockCode=23342, purch=1),
#  Row(custId=16150, stockCode=23397, purch=1),
#  Row(custId=13983, stockCode=23376, purch=1),
#  Row(custId=16211, stockCode=21340, purch=1),
#  Row(custId=16211, stockCode=22940, purch=1),
#  Row(custId=16984, stockCode=22539, purch=1),
#  Row(custId=16984, stockCode=22339, purch=1),
#  Row(custId=16984, stockCode=21539, purch=1),
#  Row(custId=12924, stockCode=23559, purch=1),
#  Row(custId=17433, stockCode=20726, purch=1),
#  Row(custId=17433, stockCode=21326, purch=1),
#  Row(custId=18069, stockCode=47594, purch=1),
#  Row(custId=12940, stockCode=22767, purch=1),
#  Row(custId=15529, stockCode=23374, purch=1),
#  Row(custId=17779, stockCode=21524, purch=1),
#  Row(custId=17228, stockCode=22111, purch=1),
#  Row(custId=17092, stockCode=22943, purch=1),
#  Row(custId=17365, stockCode=22042, purch=1),
#  Row(custId=14096, stockCode=22595, purch=1),
#  Row(custId=16161, stockCode=23390, purch=1),
#  Row(custId=16081, stockCode=22750, purch=1),
#  Row(custId=16081, stockCode=85150, purch=1),
#  Row(custId=14753, stockCode=22086, purch=1),
#  Row(custId=13704, stockCode=22699, purch=1),
#  Row(custId=16469, stockCode=21794, purch=1),
#  Row(custId=13588, stockCode=21591, purch=1),
#  Row(custId=13860, stockCode=20727, purch=1),
#  Row(custId=15804, stockCode=23399, purch=1),
#  Row(custId=16910, stockCode=22077, purch=1),
#  Row(custId=17786, stockCode=22865, purch=1),
#  Row(custId=17434, stockCode=21889, purch=1),
#  Row(custId=17428, stockCode=23311, purch=1),
#  Row(custId=17530, stockCode=22737, purch=1),
#  Row(custId=16108, stockCode=23551, purch=1),
#  Row(custId=13418, stockCode=22681, purch=1),
#  Row(custId=15240, stockCode=22867, purch=1),
#  Row(custId=18055, stockCode=23112, purch=1),
#  Row(custId=14487, stockCode=21928, purch=1),
#  Row(custId=16438, stockCode=72741, purch=1),
#  Row(custId=14769, stockCode=22494, purch=1),
#  Row(custId=14769, stockCode=82494, purch=1),
#  Row(custId=14769, stockCode=23294, purch=1),
#  Row(custId=14684, stockCode=23439, purch=1),
#  Row(custId=14735, stockCode=22752, purch=1),
#  Row(custId=12640, stockCode=22467, purch=1),
#  Row(custId=13774, stockCode=22909, purch=1),
#  Row(custId=15594, stockCode=16169, purch=1),
#  Row(custId=12497, stockCode=22558, purch=1),
#  Row(custId=12724, stockCode=23559, purch=1),
#  Row(custId=12724, stockCode=21559, purch=1),
#  Row(custId=14356, stockCode=84375, purch=1),
#  Row(custId=13416, stockCode=23355, purch=1),
#  Row(custId=14236, stockCode=21215, purch=1),
#  Row(custId=15341, stockCode=21930, purch=1),
#  Row(custId=17034, stockCode=23089, purch=1),
#  Row(custId=14356, stockCode=23175, purch=1),
#  Row(custId=16016, stockCode=23355, purch=1),
#  Row(custId=13350, stockCode=23397, purch=1),
#  Row(custId=14096, stockCode=22195, purch=1),
#  Row(custId=14428, stockCode=23111, purch=1),
#  Row(custId=16213, stockCode=85066, purch=1),
#  Row(custId=17243, stockCode=23356, purch=1),
#  Row(custId=14395, stockCode=23332, purch=1),
#  Row(custId=15067, stockCode=23268, purch=1),
#  Row(custId=15484, stockCode=23239, purch=1),
#  Row(custId=12936, stockCode=21915, purch=1),
#  Row(custId=15640, stockCode=23267, purch=1),
#  Row(custId=14113, stockCode=22966, purch=1),
#  Row(custId=15194, stockCode=22169, purch=1),
#  Row(custId=13004, stockCode=23399, purch=1),
#  Row(custId=12546, stockCode=22745, purch=1),
#  Row(custId=17416, stockCode=23355, purch=1),
#  Row(custId=14215, stockCode=21992, purch=1),
#  Row(custId=15714, stockCode=21929, purch=1),
#  Row(custId=15763, stockCode=21116, purch=1),
#  Row(custId=15901, stockCode=22210, purch=1),
#  Row(custId=18188, stockCode=21791, purch=1),
#  Row(custId=14546, stockCode=84945, purch=1),
#  Row(custId=16240, stockCode=22867, purch=1),
#  Row(custId=14652, stockCode=90023, purch=1),
#  Row(custId=15978, stockCode=22961, purch=1),
#  Row(custId=15799, stockCode=20984, purch=1),
#  Row(custId=17107, stockCode=22188, purch=1),
#  Row(custId=16771, stockCode=22620, purch=1),
#  Row(custId=15154, stockCode=75049, purch=1),
#  Row(custId=18016, stockCode=23355, purch=1),
#  Row(custId=15243, stockCode=21156, purch=1),
#  Row(custId=17997, stockCode=15058, purch=1),
#  Row(custId=15754, stockCode=85049, purch=1),
#  Row(custId=14818, stockCode=22481, purch=1),
#  Row(custId=14456, stockCode=22475, purch=1),
#  Row(custId=13979, stockCode=20724, purch=1),
#  Row(custId=15674, stockCode=22609, purch=1),
#  Row(custId=17576, stockCode=22835, purch=1),
#  Row(custId=17405, stockCode=22362, purch=1),
#  Row(custId=16460, stockCode=21327, purch=1),
#  Row(custId=13842, stockCode=23393, purch=1),
#  Row(custId=12615, stockCode=22992, purch=1),
#  Row(custId=14524, stockCode=22959, purch=1),
#  Row(custId=16653, stockCode=21786, purch=1),
#  Row(custId=16653, stockCode=22986, purch=1),
#  Row(custId=16574, stockCode=22909, purch=1),
#  Row(custId=15955, stockCode=21212, purch=1),
#  Row(custId=16589, stockCode=23354, purch=1),
#  Row(custId=17813, stockCode=85066, purch=1),
#  Row(custId=17813, stockCode=22866, purch=1),
#  Row(custId=17813, stockCode=22666, purch=1),
#  Row(custId=16268, stockCode=23231, purch=1),
#  Row(custId=14422, stockCode=23333, purch=1),
#  Row(custId=12694, stockCode=22669, purch=1),
#  Row(custId=15172, stockCode=22583, purch=1),
#  Row(custId=16923, stockCode=23396, purch=1),
#  Row(custId=15906, stockCode=21625, purch=1),
#  Row(custId=17841, stockCode=20830, purch=1),
#  Row(custId=14432, stockCode=22163, purch=1),
#  Row(custId=14488, stockCode=22491, purch=1),
#  Row(custId=14488, stockCode=21891, purch=1),
#  Row(custId=16747, stockCode=22708, purch=1),
#  Row(custId=14815, stockCode=23192, purch=1),
#  Row(custId=15930, stockCode=23537, purch=1),
#  Row(custId=13994, stockCode=23169, purch=1),
#  Row(custId=15241, stockCode=23230, purch=1),
#  Row(custId=13801, stockCode=84510, purch=1),
#  Row(custId=16360, stockCode=85227, purch=1),
#  Row(custId=15046, stockCode=85045, purch=1),
#  Row(custId=13317, stockCode=23218, purch=1),
#  Row(custId=16033, stockCode=23526, purch=1),
#  Row(custId=14506, stockCode=22825, purch=1),
#  Row(custId=12512, stockCode=22203, purch=1),
#  Row(custId=15249, stockCode=23534, purch=1),
#  Row(custId=12415, stockCode=23392, purch=1),
#  Row(custId=12415, stockCode=22192, purch=1),
#  Row(custId=15628, stockCode=23311, purch=1),
#  Row(custId=16040, stockCode=22867, purch=1),
#  Row(custId=14730, stockCode=22537, purch=1),
#  Row(custId=14730, stockCode=22737, purch=1),
#  Row(custId=15106, stockCode=23225, purch=1),
#  ...]

# %% [markdown]
# ### 2.5 - Randomly split the data into a testing set (10% of the data), a cross validation set (10% of the data) a training set (80% of the data)
# <br><br>
# We wish to split up the data into three parts.   A training set (80%) to train the algorithm, a testing set (10%) and a cross-validation set (10%).   The data for each set should be randomly selected.
# <br><br>
#  <div class="panel-group" id="accordion-25">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-25" href="#collapse1-25">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-25" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.randomSplit">randomSplit()</a></i> method</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-25" href="#collapse2-25">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-25" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#       testDf, cvDf, trainDf = uniqueCombDf.randomSplit([.1,.1,.8])<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-25" href="#collapse3-25">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse3-25" class="panel-collapse collapse">
#       <div class="panel-body"><i>randomSplit()</i> takes an optional seed parameter.  At the end of the exercise give a random seed and see whether the results change.</div>
#     </div>
#   </div>
# </div>

# %%
testDf, cvDf, trainDf = uniqueCombDf.randomSplit([.1,.1,.8])
testDf.collect()

# %% [markdown]
# ## Step 3 - Build recommendation models
#
# ### 3.1 - Use the training dataframe to train a model with Alternating Least Squares using the <i><a href="https://spark.apache.org/docs/1.6.1/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS">ALS</a></i> class
# <br>
# ALS attempts to estimate the ratings matrix R as the product of two lower-rank matrices, X and Y, i.e. X * Yt = R. Typically these approximations are called ‘factor’ matrices. The general approach is iterative. During each iteration, one of the factor matrices is held constant, while the other is solved for using least squares. The newly-solved factor matrix is then held constant while solving for the other factor matrix.
# <br><br>
# Latent Factors / rank<br>
# &nbsp;&nbsp;&nbsp;&nbsp;The number of columns in the user-feature and product-feature matricies<br>
# Iterations / maxIter<br>
# &nbsp;&nbsp;&nbsp;&nbsp;The number of factorization runs<br><br>
# To use the ALS class type:
# <br>
# from pyspark.ml.recommendation import ALS<br>
# <br>
# When running ALS, we need to create two separate instances.   For both instances userCol is custId, itemCol is stockCode and ratingCol is purch.<br><br>
# For the first instance, use a rank of 15 and set iterations to 5.<br>
# For the second instance, use a rank of 2 and set iterations to 10.<br>
# Run <i><a href="https://spark.apache.org/docs/1.6.1/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS.fit">fit()</a></i> on both instances using the training dataframe.<br>
# <br>
#  <div class="panel-group" id="accordion-31">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse1-31">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-31" class="panel-collapse collapse">
#       <div class="panel-body">Create an emply instance of the <i>ALS</i> class and run the <i>explainParams</i> method on it to see the default values.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse2-31">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse2-31" class="panel-collapse collapse">
#       <div class="panel-body">als1 = ALS(rank=15, maxIter=5, userCol="custId", itemCol="stockCode", ratingCol="purch")</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse3-31">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse3-31" class="panel-collapse collapse">
#       <div class="panel-body">model1 = als1.fit(trainDf)</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-31" href="#collapse4-31">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse4-31" class="panel-collapse collapse">
#       <div class="panel-body">Type:
# <br>
# from pyspark.ml.recommendation import ALS<br>
#
# als1 = ALS(rank=15, maxIter=5, userCol="custId", itemCol="stockCode", ratingCol="purch")<br>
# model1 = als1.fit(trainDf)<br>
#
# als2 = ALS(rank=2, maxIter=10, userCol="custId", itemCol="stockCode", ratingCol="purch")<br>
# model2 = als2.fit(trainDf)
# </div>
#     </div>
#   </div>
# </div>

# %%
from pyspark.ml.recommendation import ALS

# %% [markdown]
# ## Step 4 - Test the models
#
# Use the models to predict what the user will rate a certain item.  The closer our model is to 1 for an item a user has already purchased, the better.
#
# ### 4.1 - Evaluate the model with the cross validation dataframe by using the transorm function.
#
# Some of the users or purchases in the cross validation data may not have been in the training data.  Let's remove the ones that aren't.   To do this obtain all the the custId and stockCode values from the training data and filter out any lines with those values from the cross-validation data.
# <br><br>
# At the end, print out how many cross-validation lines we had at the start -- and the new number afterwords.
# <br><br>
#  <div class="panel-group" id="accordion-41">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-41" href="#collapse1-41">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-41" class="panel-collapse collapse">
#       <div class="panel-body">Use <i>map()</i> to return a specific value (i.e. foo = foo.map(lambda x: x.value)) and put them all in a set (i.e. foo1 = set(foo))<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-41" href="#collapse2-41">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-41" class="panel-collapse collapse">
#       <div class="panel-body">You need all the returned values (remember they might be spread all across the cluster!) so run collect() on the results of the map(). (i.e. foo1 = set(foo.collect()))</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-41" href="#collapse3-41">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-41" class="panel-collapse collapse">
#       <div class="panel-body">Use the <i>filter()</i> to filter out any values in the cross-validation dataframe which are in the stockCode or custId sets.   Use <i>toDF()</i> to change the results to a dataframe.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-41" href="#collapse4-41">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-41" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# customers = set(trainDf.rdd.map(lambda line: line.custId).collect())<br>
# stock = set(trainDf.rdd.map(lambda line: line.stockCode).collect())<br>
#
# filteredCvDf = cvDf.rdd.filter(lambda line: line.stockCode in stock and line.custId in customers).toDF()<br>
#
# print cvDf.count()<br>
# print filteredCvDf.count()<br></div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ### Step 4.2 - Make Predictions using <i><a href="https://spark.apache.org/docs/1.6.1/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALSModel.transform">transform()</a></i>
#
# Type:
#
# predictions1 = model1.transform(filteredCvDf)<br>
# predictions2 = model2.transform(filteredCvDf)
# </font>

# %% [markdown]
# ### 4.3 - Calculate and print the Mean Squared Error.   For all ratings, subtract the prediction from the actual purchase (1), square the result, and take the mean of all of the squared differences.
#
# The lower the result number, the better the model.
#
# Type:
#
# meanSquaredError1 = predictions1.map(lambda line: (line.purch - line.prediction)\*\*2).mean()<br>
# meanSquaredError2 = predictions2.map(lambda line: (line.purch - line.prediction)\*\*2).mean()<br><br>
#
# print 'Mean squared error = %.4f for our first model' % meanSquaredError1<br>
# print 'Mean squared error = %.4f for our second model' % meanSquaredError2

# %% [markdown]
# ### 4.4 - Confirm the model by testing it with the test data and the best hyperparameters found during cross-validation
#
# Filter the test dataframe (testDf) the same way as the cross-validation dataframe.   Then run the transform() and calculate the mean squared error.   It should be the same as the value calcuated above.
#
# Type:
#
# filteredTestDf = testDf.rdd.filter(lambda line: line.stockCode in stock and line.custId in customers).toDF()<br>
# predictions3 = model2.transform(filteredTestDf)<br>
# meanSquaredError3 = predictions3.map(lambda line: (line.purch - line.prediction)\*\*2).mean()<br><br>
#
# print 'Mean squared error = %.4f for our best model' % meanSquaredError3

# %% [markdown]
# ## Step 5 - Implement the model
#
# ### 5.1 - First, create a dataframe in which each row has the user id and an item id.
# <br>
# Use the <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame">Dataframe</a></i> methods to create a Dataframe with a specific user and that user's purchased products.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;First, use the Dataframe <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.filter">filter()</a></i> to filter out all custId's but 15544.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;Then use the <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.select">select()</a></i> to only return the <i>custId</i> column.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;Now use <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.distinct">distinct()</a></i> to ensure we only have the single custId.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;Do a <i><a href="https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.join">join()</a></i> with the distinct values from the stockCode column.
# <br><br>
#  <div class="panel-group" id="accordion-51">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse1-51">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-51" class="panel-collapse collapse">
#       <div class="panel-body">Use the Dataframe <i>filter()</i> method to filter out all users but 15544<br>
#       user = trainDf.filter(trainDf.custId == 15544)<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse2-51">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-51" class="panel-collapse collapse">
#       <div class="panel-body">Use the Dataframe <i>select()</i> method to only select the custId column<br>
#       userCustId = user.select("custId")</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse3-51">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-51" class="panel-collapse collapse">
#       <div class="panel-body">Use the Dataframe <i>distinct()</i> method to only return unique rows.<br>
#       userCustIdDistinct = userCustId.distinct()</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse4-51">
#         Hint 4</a>
#       </h4>
#     </div>
#     <div id="collapse4-51" class="panel-collapse collapse">
#       <div class="panel-body">Use the Dataframe <i>join()</i> method to join the results with distinct stockCodes</div>
#     </div>
#   </div>
#     <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-51" href="#collapse4-51">
#         Hint 5</a>
#       </h4>
#     </div>
#     <div id="collapse5-51" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
# user = trainDf.filter(trainDf.custId == 15544)<br>
# userCustId = user.select("custId")<br>
# userCustIdDistinct = userCustId.distinct()<br>
# stockCode = trainDf.select("stockCode")<br>
# stockCodeDistinct = stockCode.distinct()<br>
# userItems = userCustIdDistinct.join(stockCodeDistinct)<br>
# OR
# userItems = trainDf.filter(trainDf.custId == 15544).select("custId").distinct().join( trainDf.select("stockCode").distinct())<br></div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ### 5.2 - Use 'transform' to rate each item.
#
# Type:
#
# bestRecsDf = model2.transform(userItems)
# bestRecsDf.first()

# %% [markdown]
# ###  5.3 - Print the top 5 recommendations sorted on prediction.
#
#  <div class="panel-group" id="accordion-53">
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-53" href="#collapse1-53">
#         Hint 1</a>
#       </h4>
#     </div>
#     <div id="collapse1-53" class="panel-collapse collapse">
#       <div class="panel-body">In order to print the top five recommendations, we need to <i><a href"https://spark.apache.org/docs/1.6.2/api/python/pyspark.sql.html#pyspark.sql.DataFrame.sort">sort()</a></i> them in descending order<br></div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-53" href="#collapse2-53">
#         Hint 2</a>
#       </h4>
#     </div>
#     <div id="collapse2-53" class="panel-collapse collapse">
#       <div class="panel-body">Use <i>take()</i> to get the top 5 values.</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-53" href="#collapse3-53">
#         Hint 3</a>
#       </h4>
#     </div>
#     <div id="collapse3-53" class="panel-collapse collapse">
#       <div class="panel-body">Type:<br>
#       print bestRecsDf.sort("prediction",ascending=False).take(5)</div>
#     </div>
#   </div>
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title">
#         <a data-toggle="collapse" data-parent="#accordion-53" href="#collapse4-53">
#         Advanced Optional 1</a>
#       </h4>
#     </div>
#     <div id="collapse4-53" class="panel-collapse collapse">
#       <div class="panel-body">select from the retailPurchases temp table on stockCode to see some of selections recommended.</div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# Let's look up this user and the recommended product ID's in the excel file...
#
# <img src='https://raw.githubusercontent.com/rosswlewis/RecommendationPoT/master/user.png' width="80%" height="80%"></img>

# %% [markdown]
# This user seems to have purchased a lot of childrens gifts and some holiday items.  The recommendation engine we created suggested some items along these lines

# %% [markdown]
# #####  Citation
# Daqing Chen, Sai Liang Sain, and Kun Guo, Data mining for the online retail industry: A case study of RFM model-based customer segmentation using data mining, Journal of Database Marketing and Customer Strategy Management, Vol. 19, No. 3, pp. 197â€“208, 2012 (Published online before print: 27 August 2012. doi: 10.1057/dbm.2012.17).
